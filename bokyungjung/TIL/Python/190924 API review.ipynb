# %% [markdown]
# # 동물보호관리시스템 유기동물 조회 서비스
#
# <https://www.data.go.kr/dataset/15001096/openapi.do>

# %% [markdown]
# 환경변수 여러 개를 한꺼번에 설정합니다.
#
# 반드시 Key, Token 등의 내용을 바꿔서 입력해 주세요.
#
# ```bash
# # 1. 공공데이터포털
# # Mac, Linux 또는 Windows Git Bash 등에선 다음과 같이 export를 사용하시면 됩니다.
# export ANIMAL_API_KEY=abcdefghijklm%2FvSfZeu4FoGpl2eGP%2FzlR5eGh%2F9M8jbOv4HPFZI%2BM7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q%3D%3D
# # Windows 기본 환경에선 다음과 같이 set을 사용하세요.
# set ANIMAL_API_KEY=abcdefghijklm%2FvSfZeu4FoGpl2eGP%2FzlR5eGh%2F9M8jbOv4HPFZI%2BM7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q%3D%3D
#
# # 2. LocationIQ
# # Mac, Linux 또는 Windows Git Bash 등에선 다음과 같이 export를 사용하시면 됩니다.
# export LOCATIONIQ_TOKEN=b023f593f83638
# # Windows 기본 환경에선 다음과 같이 set을 사용하세요.
# set LOCATIONIQ_TOKEN=b023f593f83638
#
# # Jupyter Notebook 실행
# jupyter notebook
# ```

# %% [markdown]
# 환경 변수에서 API 키를 가져옵니다.

# %%
# 환경 변수에서 API 키 가져오기

import os
from urllib.parse import unquote

# 공공데이터포털에서 얻은 key는 unquote() 사용해야함
API_KEY = unquote(os.environ['ANIMAL_API_KEY'])
LOCATIONIQ_TOKEN = os.environ['LOCATIONIQ_TOKEN']

# %% [markdown]
# ## 라이브러리 사용

# %%
# requests 사용

import requests

requests.__version__
# Out:
# '2.22.0'

# %%
# Pandas 사용

import pandas as pd

pd.__version__
# Out:
# '0.24.2'

# %%
# Matplotlib 사용

import matplotlib
import matplotlib.pyplot as plt

matplotlib.__version__
# Out:
# '3.1.0'

# %%
# matplotlib에 “AppleGothc”(Mac) 또는 “Malgun Gothic”(Windows) 글꼴 적용

import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break

plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
# folium 패키지 설치

# !pip install folium

# %%
# folium 버전 확인

import folium

folium.__version__
# Out:
# '0.10.0'

# %%
# folium 라이브러리의 Map과 HeatMap 사용

from folium import Map
from folium.plugins import HeatMap

# %% [markdown]
# ## 동물보호관리시스템 유기동물 조회 서비스 API 사용
#
# 많은 데이터를 다루기 위해 한꺼번에 만 개를 얻어오겠습니다.

# %%
# 동물보호관리시스템 유기동물 조회 서비스 API

# 원래 URL: http://openapi.animal.go.kr/.../abandonmentPublic?serviceKey=어쩌고&bgnde=20190901&...

# 이렇게 긴 URL을 물음표(?)를 기준으로 두 부분으로 나눕니다.

# 물음표(?) 앞부분
url = 'http://openapi.animal.go.kr/openapi/service/rest/abandonmentPublicSrvc/abandonmentPublic'

# 물음표(?) 뒷부분
payload = {
    'serviceKey': API_KEY,
    'bgnde': '20190901',
    'endde': '20190930',
    'numOfRows': 100,
}

# API 호출
response = requests.get(url, params=payload)

print(response)
# Out:
# <Response [200]>

# %%
# Response의 Text 길이 확인

len(response.text)
# Out:
# 78782

# %% [markdown]
# 표현에 주목해 보세요.
# `reponse`는 응답이고, `response.text`는 응답 받은 내용입니다.
# 우리가 파싱해야 하는 대상은 `response.text`겠죠?
#
# 파싱을 하면 우리가 다루기 좋은 트리가 만들어집니다.
#
# <https://en.wikipedia.org/wiki/Tree_(data_structure)>
#
# 컴퓨터의 폴더 구조가 전형적인 트리죠.
#
# 트리의 가장 중요한 특징은 우리가 뿌리를 통해 나무 전체를 다룰 수 있다는 겁니다.
# 예를 들어, Windows의 경우 `C:\`(C 드라이브 루트)에서 출발하면 모든 파일에 접근할 수 있죠.

# %%
# XML 데이터 파싱

import xml.etree.ElementTree as ET

root = ET.fromstring(response.text)

root
# Out:
# <Element 'response' at 0x0000023AF6903EA8>

# %% [markdown]
# XML에 있던 `<item>` 항목을 모두 얻어보겠습니다.
#
# ElementTree는 파이썬의 Iterator를 활용해서 이 기능을 제공합니다.
#
# <https://wiki.python.org/moin/Iterator>
#
# Iterator는 글을 읽는 어린아이의 손가락 같은 역할을 합니다.
# 지금 가르킨 글자를 읽고 다음 글자로 넘어가죠.

# %%
# 첫번째 내용을 얻고 다음으로 넘어갑니다.

item = next(root.iter('item'))

# Item에 어떤 내용이 있는지 확인합니다.

list(item)
# Out:
# [<Element 'age' at 0x0000023AF6935688>,
#  <Element 'careAddr' at 0x0000023AF69356D8>,
#  <Element 'careNm' at 0x0000023AF6935728>,
#  <Element 'careTel' at 0x0000023AF6935778>,
#  <Element 'chargeNm' at 0x0000023AF69357C8>,
#  <Element 'colorCd' at 0x0000023AF6935818>,
#  <Element 'desertionNo' at 0x0000023AF6935868>,
#  <Element 'filename' at 0x0000023AF69358B8>,
#  <Element 'happenDt' at 0x0000023AF6935908>,
#  <Element 'happenPlace' at 0x0000023AF6935958>,
#  <Element 'kindCd' at 0x0000023AF69359A8>,
#  <Element 'neuterYn' at 0x0000023AF69359F8>,
#  <Element 'noticeEdt' at 0x0000023AF6935A48>,
#  <Element 'noticeNo' at 0x0000023AF6935A98>,
#  <Element 'noticeSdt' at 0x0000023AF6935AE8>,
#  <Element 'officetel' at 0x0000023AF6935B38>,
#  <Element 'orgNm' at 0x0000023AF6935B88>,
#  <Element 'popfile' at 0x0000023AF6935BD8>,
#  <Element 'processState' at 0x0000023AF6935C28>,
#  <Element 'sexCd' at 0x0000023AF6935C78>,
#  <Element 'specialMark' at 0x0000023AF6935CC8>,
#  <Element 'weight' at 0x0000023AF6935D18>]

# %%
# <kindCd> 항목을 확인해 봅니다.
# 트리에서 바로 아래에 있는 걸 “자녀”라고 부릅니다.

child = item.find('kindCd')

print(child)
# Out:
# <Element 'kindCd' at 0x0000023AF69359A8>

# %%
# 자녀의 내용(text)을 확인해 봅니다.

print(child.text)
# Out:
# [개] 믹스견

# %%
# 이게 뭐였죠?

print(child.tag, child.text)
# Out:
# kindCd [개] 믹스견

# %% [markdown]
# XML은 key와 value를 다루는데 유용합니다.
# 파이썬의 Dictionary와 같죠.
#
# 데이터:
#
# ```text
# 이름: 홍길동
# 나이: 13세
# ```
#
# 파이썬:
#
# ```python
# {
#     'name': '홍길동',
#     'age:' 13
# }
# ```
#
# XML:
#
# ```xml
# <person>
#     <name>홍길동</name>
#     <age>13</age>
# </person>
# ```
#
# `person`, `name`, `age` 등이 태그(tag)에 해당합니다.

# %%
# item의 모든 자녀 확인

for child in item:
    print(child.tag, child.text)
# Out:
# age 2016(년생)
# careAddr 경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원
# careNm 태민동물병원
# careTel 055-931-7975
# chargeNm 박중언
# colorCd 흰색
# desertionNo 448548201900232
# filename http://www.animal.go.kr/files/shelter/2019/09/201909260809844_s.jpg
# happenDt 20190926
# happenPlace 용주면 고품2구 부흥리
# kindCd [개] 믹스견
# neuterYn N
# noticeEdt 20191007
# noticeNo 경남-합천-2019-00284
# noticeSdt 20190926
# officetel 055-930-3562
# orgNm 경상남도 합천군
# popfile http://www.animal.go.kr/files/shelter/2019/09/201909260809844.jpg
# processState 보호중
# sexCd F
# specialMark 활발하고 건강함
# weight 10(Kg)

# %% [markdown]
# 태그만 모아서 컬럼으로 활용합시다.

# %%
# 컬럼 목록 얻기

item = next(root.iter('item'))

columns = []

for child in item:
    columns.append(child.tag)

columns
# Out:
# ['age',
#  'careAddr',
#  'careNm',
#  'careTel',
#  'chargeNm',
#  'colorCd',
#  'desertionNo',
#  'filename',
#  'happenDt',
#  'happenPlace',
#  'kindCd',
#  'neuterYn',
#  'noticeEdt',
#  'noticeNo',
#  'noticeSdt',
#  'officetel',
#  'orgNm',
#  'popfile',
#  'processState',
#  'sexCd',
#  'specialMark',
#  'weight']

# %% [markdown]
# 항상 최종 형태를 먼저 생각합니다.
# 테스트 코드로 쓰는 게 가장 좋고, 여의치 않다면 그에 준하는 모양을 간단히 잡아봅니다.
#
# Pandas로 다루는 2차원 데이터는 Column과 Row의 조화를 통해 구성되죠.
#
# Column은 이름이 있고, key-value 형태(`dictionary`)를 쓰면 매우 좋습니다.
#
# Row는 그냥 `list`로 충분하죠.
#
# 즉, 데이터는 `dictionary`의 `list`가 됩니다.
#
# ```python
# # item이 없을 때
# rows = []
#
# # item이 하나일 때
# rows = [
#     { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' }
# ]
#
# # item이 여럿일 때
# rows = [
#     { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' },
#     { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' },
#     { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' }
# ]
# ```
#
# 사실 2차원 데이터는 항상 이 모양이라고 보셔도 무방합니다.

# %%
# XML 데이터를 Pandas DataFrame으로 변환

# dictionary의 list를 준비합니다. 처음엔 0개죠.
rows = []

# item을 하나씩 rows에 넣을 겁니다.
for item in root.iter('item'):
    # 일단 row를 준비합니다. 단수형과 복수형을 구분해서 쓰니까 주의하세요.
    row = {}
    # item의 자녀를 하나씩 row에 넣을 겁니다.
    # 이런 코드가 나오면 앞에 나온 for는 잊어버리세요.
    # 지금부터 나오는 것에 집중하세요.
    for child in list(item):
        # dictionary는 key와 value를 함께 써서 추가 또는 변경합니다.
        # tag와 text가 헷갈리면 바로 위에 나온 ElementTree를 다시 확인하세요.
        # tag와 text는 보편적인 표현이 아닙니다.
        # A라는 폴더의 README.md 파일과 B라는 폴더의 README.md 파일은 이름이 같지만 전혀 다릅니다.
        # 어떤 게 들어있는지는 직접 열어보기 전에는 알 수 없습니다.
        # “모르는 것 발견 = 지금 당장 확인”을 습관으로 만드세요. 손은 눈보다 빠릅니다.
        row[child.tag] = child.text
    # 이렇게 블록이 끝나면 방금 있던 for를 잊으세요.
    # 우리가 얻은 건 item의 자녀 내용이 들어간 row죠.
    # 이제 이걸 rows(단수형과 복수형에 주의하세요)에 넣어줍니다.
    # list는 append를 썼죠?
    rows.append(row)

# dictionary의 list는 Pandas의 DataFrame으로 쉽게 변경 가능합니다.

df = pd.DataFrame(rows, columns=columns)

# %%
# 1. 컬럼 목록

df.columns
# Out:
# Index(['age', 'careAddr', 'careNm', 'careTel', 'chargeNm', 'colorCd',
#        'desertionNo', 'filename', 'happenDt', 'happenPlace', 'kindCd',
#        'neuterYn', 'noticeEdt', 'noticeNo', 'noticeSdt', 'officetel', 'orgNm',
#        'popfile', 'processState', 'sexCd', 'specialMark', 'weight'],
#       dtype='object')

# %%
# 2. 전체 갯수와 컬럼 갯수 확인

df.shape
# Out:
# (100, 22)

# %%
# 3. 데이터 일부 확인

df.head()
# Out:
#         age                                   careAddr     careNm  \
# 0  2016(년생)     경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원     태민동물병원
# 1  2017(년생)     경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원     태민동물병원
# 2  2018(년생)        경상남도 통영시 광도면 죽림3로 33 (광도면) 사랑애완동물병원   사랑애완동물병원
# 3  2019(년생)        경상남도 통영시 광도면 죽림3로 33 (광도면) 사랑애완동물병원   사랑애완동물병원
# 4  2019(년생)  경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지   진해유기동물보호소
#
#         careTel chargeNm    colorCd      desertionNo  \
# 0  055-931-7975      박중언         흰색  448548201900232
# 1  055-931-7975      박중언      갈색,흰색  448548201900231
# 2  055-648-7582      박정재    연갈색/크림색  448533201900660
# 3  055-648-7582      박정재  갈색/크림색/흰색  448533201900659
# 4  055-225-5483      진해구         흰색  448532201900789
#
#                                             filename  happenDt   happenPlace  \
# 0  http://www.animal.go.kr/files/shelter/2019/09/...  20190926  용주면 고품2구 부흥리
# 1  http://www.animal.go.kr/files/shelter/2019/09/...  20190926  용주면 고품2구 부흥리
# 2  http://www.animal.go.kr/files/shelter/2019/09/...  20190926      한산도수산 근처
# 3  http://www.animal.go.kr/files/shelter/2019/09/...  20190926     도천동 257-1
# 4  http://www.animal.go.kr/files/shelter/2019/09/...  20190926     진해유기동물보호소
#
#    ... noticeEdt           noticeNo noticeSdt     officetel         orgNm  \
# 0  ...  20191007   경남-합천-2019-00284  20190926  055-930-3562      경상남도 합천군
# 1  ...  20191007   경남-합천-2019-00283  20190926  055-930-3562      경상남도 합천군
# 2  ...  20191007   경남-통영-2019-00445  20190926  055-650-6252      경상남도 통영시
# 3  ...  20191007   경남-통영-2019-00444  20190926  055-650-6252      경상남도 통영시
# 4  ...  20191007  경남-창원3-2019-00458  20190926  055-225-5483  경상남도 창원시 진해구
#
#                                              popfile processState sexCd  \
# 0  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 1  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 2  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 3  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 4  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
#
#                        specialMark    weight
# 0                         활발하고 건강함    10(Kg)
# 1                     사람을 잘따르고 온순함     8(Kg)
# 2                밧줄노끈 착용,굉장히 겁이 많음   7.7(Kg)
# 3  생후 7일령의 너무어린 자묘,출산한 모견과 합사/케어 중  0.09(Kg)
# 4   1개월, 남매들이 다 닮음, 사람손길을 좋아하는 아이.   1.3(Kg)
#
# [5 rows x 22 columns]

# %%
# 컬럼별 결측값 갯수 확인

data = df.isnull().sum()

pd.DataFrame(data)
# Out:
#               0
# age           0
# careAddr      0
# careNm        0
# careTel       0
# chargeNm      2
# colorCd       0
# desertionNo   0
# filename      0
# happenDt      0
# happenPlace   0
# kindCd        0
# neuterYn      0
# noticeEdt     0
# noticeNo      0
# noticeSdt     0
# officetel     0
# orgNm         0
# popfile       0
# processState  0
# sexCd         0
# specialMark   0
# weight        0

# %%
# 안 쓰는 컬럼 이름을 넣어 drop해서 simple 데이터 만들기

simple_df = df.drop(columns=[
    'careTel', 'desertionNo', 'filename',
    'noticeEdt', 'noticeNo', 'noticeSdt', 'officetel', 'popfile'
])

# 정리된 데이터 확인

simple_df.head()
# Out:
#         age                                   careAddr     careNm chargeNm  \
# 0  2016(년생)     경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원     태민동물병원      박중언
# 1  2017(년생)     경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원     태민동물병원      박중언
# 2  2018(년생)        경상남도 통영시 광도면 죽림3로 33 (광도면) 사랑애완동물병원   사랑애완동물병원      박정재
# 3  2019(년생)        경상남도 통영시 광도면 죽림3로 33 (광도면) 사랑애완동물병원   사랑애완동물병원      박정재
# 4  2019(년생)  경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지   진해유기동물보호소      진해구
#
#      colorCd  happenDt   happenPlace        kindCd neuterYn         orgNm  \
# 0         흰색  20190926  용주면 고품2구 부흥리       [개] 믹스견        N      경상남도 합천군
# 1      갈색,흰색  20190926  용주면 고품2구 부흥리       [개] 믹스견        N      경상남도 합천군
# 2    연갈색/크림색  20190926      한산도수산 근처       [개] 믹스견        N      경상남도 통영시
# 3  갈색/크림색/흰색  20190926     도천동 257-1  [고양이] 한국 고양이        N      경상남도 통영시
# 4         흰색  20190926     진해유기동물보호소       [개] 믹스견        N  경상남도 창원시 진해구
#
#   processState sexCd                      specialMark    weight
# 0          보호중     F                         활발하고 건강함    10(Kg)
# 1          보호중     F                     사람을 잘따르고 온순함     8(Kg)
# 2          보호중     M                밧줄노끈 착용,굉장히 겁이 많음   7.7(Kg)
# 3          보호중     M  생후 7일령의 너무어린 자묘,출산한 모견과 합사/케어 중  0.09(Kg)
# 4          보호중     M   1개월, 남매들이 다 닮음, 사람손길을 좋아하는 아이.   1.3(Kg)

# %% [markdown]
# ## 데이터 살펴보기

# %%
# 갯수 세기

data = simple_df['age'].value_counts()

pd.DataFrame(data)
# Out:
#           age
# 2019(년생)   55
# 2018(년생)   16
# 2017(년생)   12
# 2016(년생)    7
# 2015(년생)    4
# 2014(년생)    3
# 2009(년생)    2
# 2011(년생)    1

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['sexCd'].value_counts()

pd.DataFrame(data)
# Out:
#    sexCd
# M     48
# F     42
# Q     10

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['neuterYn'].value_counts()

pd.DataFrame(data)
# Out:
#    neuterYn
# N        64
# U        30
# Y         6

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['kindCd'].value_counts()

pd.DataFrame(data)
# Out:
#                 kindCd
# [개] 믹스견             53
# [고양이] 한국 고양이        24
# [개] 말티즈              4
# [개] 푸들               3
# [개] 진도견              3
# [개] 웰시 코기 펨브로크       2
# [고양이] 터키시 앙고라        1
# [개] 비글               1
# [개] 골든 리트리버          1
# [개] 비숑 프리제           1
# [개] 퍼그               1
# [개] 핏불테리어            1
# [개] 포메라니안            1
# [개] 보더 콜리            1
# [개] 토이 푸들            1
# [개] 시츄               1
# [개] 코카 스파니엘          1

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['colorCd'].value_counts()

pd.DataFrame(data)
# Out:
#                 colorCd
# 갈색                   14
# 흰색                   13
# 갈백                    5
# 흰                     5
# 검정색                   4
# 검정                    4
# 백                     3
# 노랑                    3
# 연갈색                   3
# 백색                    3
# 흰,검,갈                 2
# 흰,검                   2
# 검흰                    2
# 삼색                    2
# 회검백                   1
# 흰갈색                   1
# 흰,검정색                 1
# 삼색이                   1
# 검백색                   1
# 황 백                   1
# 갈색/검정                 1
# 황 백 흑                 1
# 백갈색                   1
# 백황                    1
# 갈                     1
# 갈흑                    1
# 기타                    1
# 연갈색/크림색               1
# 흰색,황색                 1
# 노랑/흰색                 1
# 흰색 갈색                 1
# 회색                    1
# 갈,흰                   1
# 갈색,흰색                 1
# 흰몸통에 검정얼굴             1
# 갈색/크림색/흰색             1
# 검, 갈, 흰색 트리플          1
# 진한갈색                  1
# 흑백                    1
# 흰,검정                  1
# 황백                    1
# 백 아이보리                1
# 갈검                    1
# 식사동 위시티 1단지앞도로        1
# 쥐색고등어                 1
# 옅은 노랑색                1
# 연한갈색                  1
# 검,백                   1
# 검정,흰색                 1

# %%
# 파이 그래프

# 데이터가 너무 많아서 20개로 제한
data = simple_df['colorCd'].value_counts().nlargest(20)

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['happenDt'].value_counts()

pd.DataFrame(data)
# Out:
#           happenDt
# 20190926       100

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 요일 구하기 (이 부분은 어렵습니다!)

DAYS = '일월화수목금토'

weekdays = []

for index in df.index:
    date = simple_df['happenDt'][index]
    # 2019년 9월 1일은 “일요일(0)”입니다.
    weekday = (int(date) - 20190901) % 7
    weekdays.append(DAYS[weekday])

simple_df = simple_df.assign(happenDay=weekdays)

simple_df.head()
# Out:
#         age                                   careAddr     careNm chargeNm  \
# 0  2016(년생)     경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원     태민동물병원      박중언
# 1  2017(년생)     경상남도 합천군 합천읍 옥산로 16 (합천읍, 까치빌라) 태민동물병원     태민동물병원      박중언
# 2  2018(년생)        경상남도 통영시 광도면 죽림3로 33 (광도면) 사랑애완동물병원   사랑애완동물병원      박정재
# 3  2019(년생)        경상남도 통영시 광도면 죽림3로 33 (광도면) 사랑애완동물병원   사랑애완동물병원      박정재
# 4  2019(년생)  경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지   진해유기동물보호소      진해구
#
#      colorCd  happenDt   happenPlace        kindCd neuterYn         orgNm  \
# 0         흰색  20190926  용주면 고품2구 부흥리       [개] 믹스견        N      경상남도 합천군
# 1      갈색,흰색  20190926  용주면 고품2구 부흥리       [개] 믹스견        N      경상남도 합천군
# 2    연갈색/크림색  20190926      한산도수산 근처       [개] 믹스견        N      경상남도 통영시
# 3  갈색/크림색/흰색  20190926     도천동 257-1  [고양이] 한국 고양이        N      경상남도 통영시
# 4         흰색  20190926     진해유기동물보호소       [개] 믹스견        N  경상남도 창원시 진해구
#
#   processState sexCd                      specialMark    weight happenDay
# 0          보호중     F                         활발하고 건강함    10(Kg)         목
# 1          보호중     F                     사람을 잘따르고 온순함     8(Kg)         목
# 2          보호중     M                밧줄노끈 착용,굉장히 겁이 많음   7.7(Kg)         목
# 3          보호중     M  생후 7일령의 너무어린 자묘,출산한 모견과 합사/케어 중  0.09(Kg)         목
# 4          보호중     M   1개월, 남매들이 다 닮음, 사람손길을 좋아하는 아이.   1.3(Kg)         목

# %%
# 갯수 세기

data = simple_df['happenDay'].value_counts()

pd.DataFrame(data)
# Out:
#    happenDay
# 목        100

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %% [markdown]
# ## 위도, 경도 얻기
#
# 반복적으로 써야 하니 함수를 만듭니다.

# %%
def geocode(address):
    url = 'https://us1.locationiq.com/v1/search.php'
    payload = {
        'key': LOCATIONIQ_TOKEN,
        'q': address,
        'format': 'json'
    }
    response = requests.get(url, params=payload)
    results = response.json()
    if 'error' in results:
        return None, None
    coordinates = results[0]
    return coordinates['lat'], coordinates['lon']

# %%
geocode('서울창업허브')
# Out:
# ('37.54662875', '126.949684293519')

# %%
geocode('수원역')
# Out:
# ('37.2658513', '127.000004233556')

# %%
# API 호출 및 지도에 표시하는 작업을 원활히 하기 위해 자료를 50개로 제한해서 sample 데이터를 만듭니다.

sample_df = simple_df.sample(n=50, random_state=1)

sample_df.shape
# Out:
# (50, 15)

# %%
# 위도, 경도 얻기

lats = []
lngs = []

for i, index in enumerate(sample_df.index):
    #print(i + 1, '-', index)
    lat, lng = geocode(sample_df['orgNm'][index])
    lats.append(lat or 0)
    lngs.append(lng or 0)

sample_df = sample_df.assign(lat=lats, lng=lngs)

sample_df.head()
# Out:
#          age                             careAddr    careNm chargeNm  \
# 80  2017(년생)   경기도 성남시 분당구 불정로 266 (수내동, 유신제일조합)   펫토피아동물병원      이소영
# 84  2019(년생)  경기도 수원시 팔달구 중부대로42번길 9 (인계동) 한성동물병원    한성동물병원      수원시
# 33  2019(년생)      충청남도 서산시 안견로 312 (읍내동, 서원빌딩) 1층  성심동물의료센터      최기항
# 81  2014(년생)   경기도 성남시 분당구 불정로 266 (수내동, 유신제일조합)   펫토피아동물병원      이소영
# 93  2019(년생)             울산광역시 남구 돋질로 232 (달동) 1층    강남동물병원      방효빈
#
#          colorCd  happenDt happenPlace        kindCd neuterYn     orgNm  \
# 80            백색  20190926    금광동 3956       [개] 말티즈        N   경기도 성남시
# 84            백황  20190926      밤밭고가차도  [고양이] 한국 고양이        U   경기도 수원시
# 33  검, 갈, 흰색 트리플  20190926  한울타리요양원 마당  [고양이] 한국 고양이        N  충청남도 서산시
# 81           백갈색  20190926  성남동 4117-1  [고양이] 한국 고양이        Y   경기도 성남시
# 93            삼색  20190926  남구 효성 2공장내  [고양이] 한국 고양이        N  울산광역시 남구
#
#    processState sexCd                specialMark    weight happenDay  \
# 80          보호중     M       꼬리 끝 주황색으로 염색 되어 있음.   3.3(Kg)         목
# 84          보호중     F                    밤밭고가차도위   0.6(Kg)         목
# 33          보호중     Q  콧물, 기침, 기립불능, 식욕부진, 많이 야윔   0.9(Kg)         목
# 81          보호중     M   다리부상, 교통사고 추정, 갈색 목줄 착용.   7.3(Kg)         목
# 93          보호중     M            호흡기질환,탈수증상,기력없슴  0.40(Kg)         목
#
#             lat               lng
# 80   37.4201556       127.1262092
# 84   37.2633325       127.0287472
# 33    36.784499        126.450317
# 81   37.4201556       127.1262092
# 93  35.49879045  129.345857526943

# %% [markdown]
# ## 지도 그리기
#
# 위도/경도 데이터를 얻었기 때문에 지도에 그려볼 수 있습니다.

# %%
# 위도, 경도만 모읍니다.

coordinates = sample_df[['lat', 'lng']]

coordinates
# Out:
#             lat               lng
# 80   37.4201556       127.1262092
# 84   37.2633325       127.0287472
# 33    36.784499        126.450317
# 81   37.4201556       127.1262092
# 93  35.49879045  129.345857526943
# 17   36.0189315       129.3429384
# 36   36.6421169       127.4891742
# 82   37.4201556       127.1262092
# 69   36.9924966       127.1127168
# 65   36.9924966       127.1127168
# 92      35.5826          129.3604
# 39   37.7525313       128.8759523
# 56   37.6581862       126.8319452
# 52  37.39931825  127.292259889877
# 51   37.8810569       127.7297641
# 32   36.0804482       126.6917006
# 31   36.8904083       126.6461833
# 44   37.8810569       127.7297641
# 78   37.3938528       126.9570605
# 10   35.9189999          128.2835
# 2     34.854254        128.433205
# 73   37.5014422       126.7660139
# 97  35.49879045  129.345857526943
# 62   36.9924966       127.1127168
# 19   36.0189315       129.3429384
# 35   36.6421169       127.4891742
# 94  35.49879045  129.345857526943
# 27   36.8904083       126.6461833
# 46   37.8810569       127.7297641
# 38      37.6967          127.8888
# 67   36.9924966       127.1127168
# 99  35.49879045  129.345857526943
# 54   37.3798891       126.8032255
# 95  35.49879045  129.345857526943
# 88      35.5219          129.2426
# 40   37.7525313       128.8759523
# 48   37.8810569       127.7297641
# 59   37.3217152       126.8308604
# 23    35.320878       126.9883238
# 34   36.6421169       127.4891742
# 86   37.2633325       127.0287472
# 53   37.2405741       127.1785572
# 77   37.3938528       126.9570605
# 15      36.2424          128.5731
# 83   37.4201556       127.1262092
# 41   37.7525313       128.8759523
# 45   37.8810569       127.7297641
# 91      35.5826          129.3604
# 26      35.6174          127.2893
# 98  35.49879045  129.345857526943

# %%
# 지도 준비

map = Map(location=[36.5, 127.5], zoom_start=7)

# 지도에 위치 표시

for lat, lng in coordinates.values:
    marker = folium.Circle(
        location=[lat, lng],
        radius=5_000,
        weight=1,
        fill_color='#F00',
        fill_opacity=0.3,
    )
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# 지도 준비

map = Map(location=[36.5, 127.5], zoom_start=7)

# 히트맵 표시

HeatMap(data=coordinates, radius=20).add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
