# %% [markdown]
# # INNER JOIN with Pandas

# %% [markdown]
# ### 렉처 중간에 예제 문제가 있습니다. 풀면서 따라와주세요!

# %%
import pandas as pd

# %% [markdown]
# # 데이터 읽기

# %%
orders = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/Orders.csv')
orderDetails = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/OrderDetails.csv')
products = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/Products.csv')
customers = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/Customers.csv')
categories = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/Categories.csv')
suppliers = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/Suppliers.csv')
shippers = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/Shippers.csv')
employees = pd.read_csv('https://raw.githubusercontent.com/dataitgirls3/Data/master/Employees.csv')

# %% [markdown]
# # 데이터 확인하기

# %%
print('columns in Orders: ' + str(list(orders.columns)))
print('columns in OrderDetails: ' + str(list(orderDetails.columns)))
print('columns in Products: ' + str(list(products.columns)))
# Out:
# columns in Orders: ['OrderID', 'CustomerID', 'EmployeeID', 'OrderDate', 'ShipperID']
# columns in OrderDetails: ['OrderDetailID', 'OrderID', 'ProductID', 'Quantity']
# columns in Products: ['ProductID', 'ProductName', 'SupplierID', 'CategoryID', 'Unit', 'Price']

# %%
print('총 ' + str(len(orders)) + '건의 주문Order 데이터')
print('총 ' + str(len(orderDetails)) + '건의 주문상세OrderDetails 데이터')
# Out:
# 총 196건의 주문Order 데이터
# 총 518건의 주문상세OrderDetails 데이터

# %% [markdown]
# Order 1 : OrderDetails N
#
# #### 테이블 관계
# - 1:1 관계
# - 1:N 관계
# - M:N 관계 → 지양

# %%
orders.head(2)
# Out:
#    OrderID  CustomerID  EmployeeID   OrderDate  ShipperID
# 0    10248          90           5  1996-07-04          3
# 1    10249          81           6  1996-07-05          1

# %%
orderDetails.head(2)
# Out:
#    OrderDetailID  OrderID  ProductID  Quantity
# 0              1    10248         11        12
# 1              2    10248         42        10

# %%
products.head(2)
# Out:
#    ProductID ProductName  SupplierID  CategoryID                Unit  Price
# 0          1       Chais           1           1  10 boxes x 20 bags   18.0
# 1          2       Chang           1           1  24 - 12 oz bottles   19.0

# %% [markdown]
# # 분석의 목표
# orders -> orderDetails -> products 를 묶어서 order 당 몇 개의 상품을 주문하는지, 종류는 얼마나 다양한지, 총 가격은 얼마인지 등을 구해보자.

# %% [markdown]
# ## Order 한 개에 얼마나 다양한 물건들이 들어있는가?
# Order 한 개 당 몇 개의 ProductID를 가지고 있는지 세보라.

# %%
'''
SELECT *
FROM Orders AS o
     INNER JOIN OrderDetails AS od ON o.OrderID = od.OrderID
'''

order_orderDetails = orders.merge(orderDetails, how='inner', on='OrderID')

# %%
order_orderDetails.head(2)
# Out:
#    OrderID  CustomerID  EmployeeID   OrderDate  ShipperID  OrderDetailID  \
# 0    10248          90           5  1996-07-04          3              1
# 1    10248          90           5  1996-07-04          3              2
#
#    ProductID  Quantity
# 0         11        12
# 1         42        10

# %%
'''
SELECT o.OrderID, COUNT(*)
FROM Orders AS o
     INNER JOIN OrderDetails AS od ON o.orderID = od.OrderID
GROUP BY o.OrderID
'''

products_per_order = order_orderDetails.groupby('OrderID').size()
products_per_order
# Out:
# OrderID
# 10248    3
# 10249    2
# 10250    3
# 10251    3
# 10252    3
# 10253    3
# 10254    3
# 10255    4
# 10256    2
# 10257    3
# 10258    3
# 10259    2
# 10260    4
# 10261    2
# 10262    3
# 10263    4
# 10264    2
# 10265    2
# 10266    1
# 10267    3
# 10268    2
# 10269    2
# 10270    2
# 10271    1
# 10272    3
# 10273    5
# 10274    2
# 10275    2
# 10276    2
# 10277    2
#         ..
# 10414    2
# 10415    2
# 10416    3
# 10417    4
# 10418    4
# 10419    2
# 10420    4
# 10421    4
# 10422    1
# 10423    2
# 10424    3
# 10425    2
# 10426    2
# 10427    1
# 10428    1
# 10429    2
# 10430    4
# 10431    3
# 10432    2
# 10433    1
# 10434    2
# 10435    3
# 10436    4
# 10437    1
# 10438    3
# 10439    4
# 10440    4
# 10441    1
# 10442    3
# 10443    2
# Length: 196, dtype: int64

# %%
# 평균적으로 1오더 당 3가지의 Product가 들어있다.
products_per_order.mean()
# Out:
# 2.642857142857143

# %% [markdown]
# ## Order 한 개에 총 몇 개의 물건이 들어있는가?

# %%
'''
SELECT o.OrderID
     , SUM(od.Quantity)
FROM Orders AS o
     INNER JOIN OrderDetails AS od ON o.OrderID = od.OrderID
GROUP BY o.OrderID
'''

num_items_per_order = order_orderDetails.groupby('OrderID')['Quantity'].sum()
num_items_per_order
# Out:
# OrderID
# 10248     27
# 10249     49
# 10250     60
# 10251     41
# 10252    105
# 10253    102
# 10254     57
# 10255    110
# 10256     27
# 10257     46
# 10258    121
# 10259     11
# 10260    102
# 10261     40
# 10262     29
# 10263    184
# 10264     60
# 10265     50
# 10266     12
# 10267    135
# 10268     14
# 10269     80
# 10270     55
# 10271     24
# 10272     70
# 10273    152
# 10274     27
# 10275     18
# 10276     25
# 10277     32
#         ...
# 10414     68
# 10415     22
# 10416     50
# 10417    123
# 10418    146
# 10419     80
# 10420     50
# 10421     59
# 10422      2
# 10423     34
# 10424    139
# 10425     30
# 10426     12
# 10427     35
# 10428     20
# 10429     75
# 10430    195
# 10431    130
# 10432     50
# 10433     28
# 10434     24
# 10435     32
# 10436     99
# 10437     15
# 10438     50
# 10439     67
# 10440    208
# 10441     50
# 10442    170
# 10443     18
# Name: Quantity, Length: 196, dtype: int64

# %%
# 한 주문 당 평균적으로 65.02개의 물건이 들어있다.
num_items_per_order.mean()
# Out:
# 65.01530612244898

# %% [markdown]
# # Quiz. 65 개 이상의 물건이 들어있는 주문의 OrderID 를 구해주세요.

# %%
order_all = orders.merge(orderDetails, how = 'inner', on='OrderID')
order_all.head()
# Out:
#    OrderID  CustomerID  EmployeeID   OrderDate  ShipperID  OrderDetailID  \
# 0    10248          90           5  1996-07-04          3              1
# 1    10248          90           5  1996-07-04          3              2
# 2    10248          90           5  1996-07-04          3              3
# 3    10249          81           6  1996-07-05          1              4
# 4    10249          81           6  1996-07-05          1              5
#
#    ProductID  Quantity
# 0         11        12
# 1         42        10
# 2         72         5
# 3         14         9
# 4         51        40

# %%
'''
SELECT OrderID, SUM(Quantity)
FROM ORDER_DETAILS
GROUP BY OrderID

'''

order_product_count = order_all.groupby('OrderID')['Quantity'].sum()

# %%
order_product_count = order_product_count.reset_index()

# %%
order_product_count[order_product_count['Quantity'] >= 65].head()
# Out:
#     OrderID  Quantity
# 4     10252       105
# 5     10253       102
# 7     10255       110
# 10    10258       121
# 12    10260       102

# %% [markdown]
# ## 주문마다 총 가격을 구해주세요.

# %%
# SQL로는 이렇게 쓸 수 있겠죠!

'''
SELECT o.OrderID
     , SUM(od.Quantity*p.Price)
FROM Orders AS o
     INNER JOIN OrderDetails AS od ON o.OrderID = od.OrderID
     INNER JOIN Products AS p ON od.ProductID = p.ProductID
GROUP BY o.OrderID
'''

'''
SELECT od.OrderID
     , SUM(od.Quantity*p.Price)
FROM OrderDetails AS od
INNER JOIN Prodeucts AS p ON od.ProductID = p.ProductID
GROUP BY od.OrderID
'''
# Out:
# '\nSELECT o.OrderID\n     , SUM(od.Quantity*p.Price)\nFROM Orders AS o\n     INNER JOIN OrderDetails AS od ON o.OrderID = od.OrderID\n     INNER JOIN Products AS p ON od.ProductID = p.ProductID\nGROUP BY o.OrderID\n'

# %% [markdown]
# # Quiz. 주문별 주문 금액을 구하세요.
# 1. OrderDetails, Products MERGE
# 2. Quantity * Price 곱한 필드를 만들어 주세요
# 3. OrderID 별로 GROUP BY SUM() 해주세요

# %%
# Merge 할 때 On 하는 Column 이름이 각자 다를 때는, left_on = '' right_on = '' 에 각각 넣어준다
# column 이 아니라 index 로 조인하고 싶을 때는, on 대신 left_index=True, right_index=True 를 넣는다
order_details_products = orderDetails.merge(products, how = 'inner', on = 'ProductID')
order_details_products.head()
# Out:
#    OrderDetailID  OrderID  ProductID  Quantity     ProductName  SupplierID  \
# 0              1    10248         11        12  Queso Cabrales           5
# 1            130    10296         11        12  Queso Cabrales           5
# 2            211    10327         11        50  Queso Cabrales           5
# 3            281    10353         11        12  Queso Cabrales           5
# 4            314    10365         11        24  Queso Cabrales           5
#
#    CategoryID       Unit  Price
# 0           4  1 kg pkg.   21.0
# 1           4  1 kg pkg.   21.0
# 2           4  1 kg pkg.   21.0
# 3           4  1 kg pkg.   21.0
# 4           4  1 kg pkg.   21.0

# %%
order_details_products['Quantity * Price'] = order_details_products['Quantity'] * order_details_products['Price']
order_details_products.head()
# Out:
#    OrderDetailID  OrderID  ProductID  Quantity     ProductName  SupplierID  \
# 0              1    10248         11        12  Queso Cabrales           5
# 1            130    10296         11        12  Queso Cabrales           5
# 2            211    10327         11        50  Queso Cabrales           5
# 3            281    10353         11        12  Queso Cabrales           5
# 4            314    10365         11        24  Queso Cabrales           5
#
#    CategoryID       Unit  Price  Quantity * Price
# 0           4  1 kg pkg.   21.0             252.0
# 1           4  1 kg pkg.   21.0             252.0
# 2           4  1 kg pkg.   21.0            1050.0
# 3           4  1 kg pkg.   21.0             252.0
# 4           4  1 kg pkg.   21.0             504.0

# %%
d = order_details_products.groupby('OrderID')['Quantity * Price'].sum()
d.head()
# Out:
# OrderID
# 10248     566.00
# 10249    2329.25
# 10250    2267.25
# 10251     839.50
# 10252    4662.50
# Name: Quantity * Price, dtype: float64

# %%
d.sort_values(ascending=False).head()
# Out:
# OrderID
# 10372    15353.60
# 10424    14366.50
# 10417    14104.00
# 10353    13427.00
# 10360     9244.25
# Name: Quantity * Price, dtype: float64

# %%
# DataFrame 은 Columns 이름을 by='Column_name' 넣어준다
d.reset_index().sort_values(by='Quantity * Price', ascending=False).head()
# Out:
#      OrderID  Quantity * Price
# 124    10372          15353.60
# 176    10424          14366.50
# 169    10417          14104.00
# 105    10353          13427.00
# 112    10360           9244.25

# %%
# 변수명 이렇게 하시면 나중에 헷갈리고 힘들어요... 저는 강의니까 그냥 이렇게 하께요 (변명)
order_all = order_orderDetails.merge(products, how='inner', on='ProductID')
order_all.head(2)
# Out:
#    OrderID  CustomerID  EmployeeID   OrderDate  ShipperID  OrderDetailID  \
# 0    10248          90           5  1996-07-04          3              1
# 1    10296          46           6  1996-09-03          1            130
#
#    ProductID  Quantity     ProductName  SupplierID  CategoryID       Unit  \
# 0         11        12  Queso Cabrales           5           4  1 kg pkg.
# 1         11        12  Queso Cabrales           5           4  1 kg pkg.
#
#    Price
# 0   21.0
# 1   21.0

# %%
# 컬럼이 너무 많으니까 일단 지금 관심 있는 것만 추려볼게요
order_all_part = order_all[['OrderID', 'OrderDate', 'Quantity', 'ProductID', 'CategoryID', 'Price']]

# %%
total_price = order_all_part['Price'] * order_all_part['Quantity']
order_all_part['TotalPricePerProduct'] = total_price
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
price_per_order = order_all_part.groupby('OrderID')['TotalPricePerProduct'].sum()
price_per_order
# Out:
# OrderID
# 10248     566.00
# 10249    2329.25
# 10250    2267.25
# 10251     839.50
# 10252    4662.50
#           ...
# 10439    1348.70
# 10440    7246.01
# 10441    2195.00
# 10442    2246.00
# 10443     673.20
# Name: TotalPricePerProduct, Length: 196, dtype: float64

# %% [markdown]
# ## 총 가격이 1000불 이상인 주문만 뽑아주세요.

# %%
# SQL로는 이렇게 쓸 수 있겠죠!

'''
SELECT o.OrderID
     , SUM(od.Quantity*p.Price) AS PricePerOrder
FROM Orders AS o
     INNER JOIN OrderDetails AS od ON o.OrderID = od.OrderID
     INNER JOIN Products AS p ON od.ProductID = p.ProductID
GROUP BY o.OrderID
HAVING PricePerOrder >= 1000
'''
# Out:
# '\nSELECT o.OrderID\n     , SUM(od.Quantity*p.Price) AS PricePerOrder\nFROM Orders AS o\n     INNER JOIN OrderDetails AS od ON o.OrderID = od.OrderID\n     INNER JOIN Products AS p ON od.ProductID = p.ProductID\nGROUP BY o.OrderID\nHAVING PricePerOrder >= 1000\n'

# %%
price_per_order[price_per_order >= 1000]
# Out:
# OrderID
# 10249    2329.25
# 10250    2267.25
# 10252    4662.50
# 10253    1806.00
# 10255    3115.75
#           ...
# 10436    2763.50
# 10439    1348.70
# 10440    7246.01
# 10441    2195.00
# 10442    2246.00
# Name: TotalPricePerProduct, Length: 118, dtype: float64

# %% [markdown]
# ### Q1. Products의 CategoryID와 Categories 테이블을 이용해서, 어떤 카테고리의 상품이 가장 많이 주문되었는지 구하세요.

# %%
ca = orders.merge(orderDetails, on='OrderID', how='inner').merge(products, on='ProductID')
ca.sample()
# ca
# Out:
#      OrderID  CustomerID  EmployeeID   OrderDate  ShipperID  OrderDetailID  \
# 418    10436           7           3  1997-02-05          2            497
#
#      ProductID  Quantity ProductName  SupplierID  CategoryID  \
# 418         46         5   Spegesild          21           8
#
#                   Unit  Price
# 418  4 - 450 g glasses   12.0

# %%
# ca.groupby('CategoryID')['CategoryName'].size()
ca['CategoryID'].value_counts()
# Out:
# 4    100
# 1     93
# 3     84
# 8     67
# 6     50
# 2     49
# 5     42
# 7     33
# Name: CategoryID, dtype: int64

# %% [markdown]
# ### Q2. Orders 테이블의 OrderDate를 이용해, 어떤 날에 주문이 가장 많았는지 알려주세요.

# %%
order_count = orders['OrderDate'].value_counts()

# %%
order_count[order_count == order_count.max()].index
# Out:
# Index(['1997-01-16', '1996-08-14', '1996-12-25', '1996-12-23', '1997-01-27',
#        '1996-12-05', '1997-01-30', '1997-02-10', '1996-10-29', '1996-12-03',
#        '1996-12-16', '1997-01-03', '1996-11-22', '1996-10-03', '1997-02-03',
#        '1997-01-23', '1996-09-09', '1996-12-09', '1996-12-18', '1997-01-21',
#        '1996-12-12', '1996-07-08', '1996-11-11', '1997-02-05', '1996-09-20',
#        '1997-01-10', '1996-08-27', '1997-01-01', '1996-11-28', '1997-01-14',
#        '1997-01-07', '1996-07-19', '1996-08-01', '1996-11-26', '1996-10-16',
#        '1996-12-27'],
#       dtype='object')

# %% [markdown]
# ### Q3. Orders 테이블의 OrderDate를 이용해, 어떤 날에 매출금액이 가장 높았는지 알려주세요.

# %%
od = orders.merge(orderDetails, on='OrderID', how='inner').merge(products, on='ProductID', how='inner')
od.sample()
# Out:
#     OrderID  CustomerID  EmployeeID   OrderDate  ShipperID  OrderDetailID  \
# 60    10401          65           1  1997-01-01          1            411
#
#     ProductID  Quantity                       ProductName  SupplierID  \
# 60         65        20  Louisiana Fiery Hot Pepper Sauce           2
#
#     CategoryID               Unit  Price
# 60           2  32 - 8 oz bottles  21.05

# %%
od['Total_Price'] = od['Quantity'] * od['Price']
od
# Out:
#      OrderID  CustomerID  EmployeeID   OrderDate  ShipperID  OrderDetailID  \
# 0      10248          90           5  1996-07-04          3              1
# 1      10296          46           6  1996-09-03          1            130
# 2      10327          24           2  1996-10-11          1            211
# 3      10353          59           7  1996-11-13          3            281
# 4      10365           3           3  1996-11-27          2            314
# 5      10407          56           2  1997-01-07          2            426
# 6      10434          24           3  1997-02-03          2            492
# 7      10442          20           3  1997-02-11          2            514
# 8      10443          66           8  1997-02-12          1            517
# 9      10248          90           5  1996-07-04          3              2
# 10     10309          37           3  1996-09-19          1            166
# 11     10311          18           1  1996-09-20          3            171
# 12     10332          51           3  1996-10-17          2            225
# 13     10345          63           2  1996-11-04          2            263
# 14     10404          49           2  1997-01-03          1            418
# 15     10248          90           5  1996-07-04          3              3
# 16     10268          33           8  1996-07-30          3             57
# 17     10269          89           5  1996-07-31          1             59
# 18     10272          65           6  1996-08-02          2             65
# 19     10274          85           6  1996-08-06          1             72
# 20     10283          46           3  1996-08-16          3             95
# 21     10297           7           5  1996-09-04          2            134
# 22     10325          39           1  1996-10-09          3            206
# 23     10330          46           3  1996-10-16          1            222
# 24     10337          25           4  1996-10-24          3            241
# 25     10372          62           5  1996-12-04          2            334
# 26     10390          20           6  1996-12-23          1            382
# 27     10396          25           1  1996-12-27          3            397
# 28     10435          16           8  1997-02-04          2            496
# 29     10249          81           6  1996-07-05          1              4
# ..       ...         ...         ...         ...        ...            ...
# 488    10353          59           7  1996-11-13          3            282
# 489    10360           7           4  1996-11-22          3            301
# 490    10372          62           5  1996-12-04          2            332
# 491    10417          73           4  1997-01-16          3            450
# 492    10424          51           7  1997-01-23          2            472
# 493    10330          46           3  1996-10-16          1            221
# 494    10337          25           4  1996-10-24          3            238
# 495    10357          46           1  1996-11-19          3            291
# 496    10393          71           1  1996-12-25          3            388
# 497    10404          49           2  1997-01-03          1            417
# 498    10421          61           8  1997-01-21          1            465
# 499    10422          27           2  1997-01-22          1            468
# 500    10432          75           3  1997-01-31          2            489
# 501    10332          51           3  1996-10-17          2            226
# 502    10418          63           4  1997-01-17          1            455
# 503    10431          10           4  1997-01-30          2            488
# 504    10337          25           4  1996-10-24          3            237
# 505    10348          86           4  1996-11-07          2            271
# 506    10396          25           1  1996-12-27          3            395
# 507    10402          20           8  1997-01-02          2            413
# 508    10344          89           4  1996-11-01          2            260
# 509    10345          63           2  1996-11-04          2            261
# 510    10350          41           6  1996-11-11          2            273
# 511    10383           4           8  1996-12-16          3            359
# 512    10429          37           3  1997-01-29          2            480
# 513    10388          72           2  1996-12-19          1            372
# 514    10403          20           4  1997-01-03          3            416
# 515    10418          63           4  1997-01-17          1            456
# 516    10440          71           4  1997-02-10          2            512
# 517    10420          88           3  1997-01-21          1            460
#
#      ProductID  Quantity                    ProductName  SupplierID  \
# 0           11        12                 Queso Cabrales           5
# 1           11        12                 Queso Cabrales           5
# 2           11        50                 Queso Cabrales           5
# 3           11        12                 Queso Cabrales           5
# 4           11        24                 Queso Cabrales           5
# 5           11        30                 Queso Cabrales           5
# 6           11         6                 Queso Cabrales           5
# 7           11        30                 Queso Cabrales           5
# 8           11         6                 Queso Cabrales           5
# 9           42        10  Singaporean Hokkien Fried Mee          20
# 10          42         2  Singaporean Hokkien Fried Mee          20
# 11          42         6  Singaporean Hokkien Fried Mee          20
# 12          42        10  Singaporean Hokkien Fried Mee          20
# 13          42         9  Singaporean Hokkien Fried Mee          20
# 14          42        40  Singaporean Hokkien Fried Mee          20
# 15          72         5         Mozzarella di Giovanni          14
# 16          72         4         Mozzarella di Giovanni          14
# 17          72        20         Mozzarella di Giovanni          14
# 18          72        24         Mozzarella di Giovanni          14
# 19          72         7         Mozzarella di Giovanni          14
# 20          72         3         Mozzarella di Giovanni          14
# 21          72        20         Mozzarella di Giovanni          14
# 22          72        40         Mozzarella di Giovanni          14
# 23          72        25         Mozzarella di Giovanni          14
# 24          72        25         Mozzarella di Giovanni          14
# 25          72        42         Mozzarella di Giovanni          14
# 26          72        24         Mozzarella di Giovanni          14
# 27          72        21         Mozzarella di Giovanni          14
# 28          72        10         Mozzarella di Giovanni          14
# 29          14         9                           Tofu           6
# ..         ...       ...                            ...         ...
# 488         38        50                  Côte de Blaye          18
# 489         38        10                  Côte de Blaye          18
# 490         38        40                  Côte de Blaye          18
# 491         38        50                  Côte de Blaye          18
# 492         38        49                  Côte de Blaye          18
# 493         26        50            Gumbär Gummibärchen          11
# 494         26        24            Gumbär Gummibärchen          11
# 495         26        16            Gumbär Gummibärchen          11
# 496         26        70            Gumbär Gummibärchen          11
# 497         26        30            Gumbär Gummibärchen          11
# 498         26        30            Gumbär Gummibärchen          11
# 499         26         2            Gumbär Gummibärchen          11
# 500         26        10            Gumbär Gummibärchen          11
# 501         47        16                  Zaanse koeken          22
# 502         47        55                  Zaanse koeken          22
# 503         47        30                  Zaanse koeken          22
# 504         23        40                       Tunnbröd           9
# 505         23        25                       Tunnbröd           9
# 506         23        40                       Tunnbröd           9
# 507         23        60                       Tunnbröd           9
# 508          8        70     Northwoods Cranberry Sauce           3
# 509          8        70     Northwoods Cranberry Sauce           3
# 510         50        15               Valkoinen suklaa          23
# 511         50        15               Valkoinen suklaa          23
# 512         50        40               Valkoinen suklaa          23
# 513         45        15                    Røgede sild          21
# 514         48        70                      Chocolade          22
# 515         61        16                 Sirop d'érable          29
# 516         61        90                 Sirop d'érable          29
# 517          9        20                Mishi Kobe Niku           4
#
#      CategoryID                 Unit   Price  Total_Price
# 0             4            1 kg pkg.   21.00       252.00
# 1             4            1 kg pkg.   21.00       252.00
# 2             4            1 kg pkg.   21.00      1050.00
# 3             4            1 kg pkg.   21.00       252.00
# 4             4            1 kg pkg.   21.00       504.00
# 5             4            1 kg pkg.   21.00       630.00
# 6             4            1 kg pkg.   21.00       126.00
# 7             4            1 kg pkg.   21.00       630.00
# 8             4            1 kg pkg.   21.00       126.00
# 9             5      32 - 1 kg pkgs.   14.00       140.00
# 10            5      32 - 1 kg pkgs.   14.00        28.00
# 11            5      32 - 1 kg pkgs.   14.00        84.00
# 12            5      32 - 1 kg pkgs.   14.00       140.00
# 13            5      32 - 1 kg pkgs.   14.00       126.00
# 14            5      32 - 1 kg pkgs.   14.00       560.00
# 15            4     24 - 200 g pkgs.   34.80       174.00
# 16            4     24 - 200 g pkgs.   34.80       139.20
# 17            4     24 - 200 g pkgs.   34.80       696.00
# 18            4     24 - 200 g pkgs.   34.80       835.20
# 19            4     24 - 200 g pkgs.   34.80       243.60
# 20            4     24 - 200 g pkgs.   34.80       104.40
# 21            4     24 - 200 g pkgs.   34.80       696.00
# 22            4     24 - 200 g pkgs.   34.80      1392.00
# 23            4     24 - 200 g pkgs.   34.80       870.00
# 24            4     24 - 200 g pkgs.   34.80       870.00
# 25            4     24 - 200 g pkgs.   34.80      1461.60
# 26            4     24 - 200 g pkgs.   34.80       835.20
# 27            4     24 - 200 g pkgs.   34.80       730.80
# 28            4     24 - 200 g pkgs.   34.80       348.00
# 29            7     40 - 100 g pkgs.   23.25       209.25
# ..          ...                  ...     ...          ...
# 488           1   12 - 75 cl bottles  263.50     13175.00
# 489           1   12 - 75 cl bottles  263.50      2635.00
# 490           1   12 - 75 cl bottles  263.50     10540.00
# 491           1   12 - 75 cl bottles  263.50     13175.00
# 492           1   12 - 75 cl bottles  263.50     12911.50
# 493           3     100 - 250 g bags   31.23      1561.50
# 494           3     100 - 250 g bags   31.23       749.52
# 495           3     100 - 250 g bags   31.23       499.68
# 496           3     100 - 250 g bags   31.23      2186.10
# 497           3     100 - 250 g bags   31.23       936.90
# 498           3     100 - 250 g bags   31.23       936.90
# 499           3     100 - 250 g bags   31.23        62.46
# 500           3     100 - 250 g bags   31.23       312.30
# 501           3      10 - 4 oz boxes    9.50       152.00
# 502           3      10 - 4 oz boxes    9.50       522.50
# 503           3      10 - 4 oz boxes    9.50       285.00
# 504           5     12 - 250 g pkgs.    9.00       360.00
# 505           5     12 - 250 g pkgs.    9.00       225.00
# 506           5     12 - 250 g pkgs.    9.00       360.00
# 507           5     12 - 250 g pkgs.    9.00       540.00
# 508           2      12 - 12 oz jars   40.00      2800.00
# 509           2      12 - 12 oz jars   40.00      2800.00
# 510           3      12 - 100 g bars   16.25       243.75
# 511           3      12 - 100 g bars   16.25       243.75
# 512           3      12 - 100 g bars   16.25       650.00
# 513           8              1k pkg.    9.50       142.50
# 514           3             10 pkgs.   12.75       892.50
# 515           2  24 - 500 ml bottles   28.50       456.00
# 516           2  24 - 500 ml bottles   28.50      2565.00
# 517           6     18 - 500 g pkgs.   97.00      1940.00
#
# [518 rows x 14 columns]

# %%
total_price = od.groupby('OrderDate')['Total_Price'].sum()
# total_price

# %%
total_price[total_price == total_price.max()]
# Out:
# OrderDate
# 1997-01-23    15641.5
# Name: Total_Price, dtype: float64

# %% [markdown]
# ### Q4 문제를 만들고, 풀어보세요!
