# %% [markdown]
# # 동물보호관리시스템 유기동물 조회 서비스
# https://www.data.go.kr/dataset/15001096/openapi.do
#
# 터미널 또는 Git Bash에서 다음을 입력해 API 키를 사용합니다.
#
#     # 환경변수 설정. 발급 받은 키로 변경해 주세요.
#     export ANIMAL_API_KEY=abcdefghijklm%2FvSfZeu4FoGpl2eGP%2FzlR5eGh%2F9M8jbOv4HPFZI%2BM7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q%3D%3D
#
#     # Jupyter Notebook 실행
#     jupyter notebook

# %%
# 환경 변수에서 API 키 가져오기

import os

key = os.environ['ANIMAL_API_KEY']

print(key)
# Out:
# XTRdBWJdl4pV1%2FvSfZeu4FoGpl2eGP%2FzlR5eGh%2F9M8jbOv4HPFZI%2BM7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q%3D%3D

# %%
# API 키 값이 URL 인코딩(encoding)된 상태라 다시 디코딩(decoding).

from urllib.parse import unquote

API_KEY = unquote(key)

print(API_KEY)
# Out:
# XTRdBWJdl4pV1/vSfZeu4FoGpl2eGP/zlR5eGh/9M8jbOv4HPFZI+M7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q==

# %%
# requests 사용

import requests

requests.__version__
# Out:
# '2.22.0'

# %% [markdown]
# # 동물보호관리시스템 유기동물 조회 서비스 API 사용
# API는 Base URL과 ? 뒤에 key=value 형태로 붙는 (연속일 경우 & 삽입) Query Parameters로 구성되어 있습니다.
#
# Base URL: http://openapi.animal.go.kr:80/openapi/service/rest/abandonmentPublicSrvc
#
# Query Parameters:
#
# * serviceKey: API 키
# * bgnde: 유기날짜 (검색 시작일) (YYYYMMDD)
# * endde: 유기날짜 (검색 종료일) (YYYYMMDD)
# * numOfRows: 페이지당 보여줄 개수

# %%
# 동물보호관리시스템 유기동물 조회 서비스 API

url = 'http://openapi.animal.go.kr/openapi/service/rest/abandonmentPublicSrvc/abandonmentPublic'

payload = {
    'serviceKey': API_KEY,
    'bgnde': '20190901',
    'endde': '20190930',
    'numOfRows': 20,
}

response = requests.get(url, params=payload)

print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><age>2019(년생)</age><careAddr>경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈퍼) </careAddr><careNm>나래동물병원</careNm><careTel>055-942-8875</careTel><chargeNm>거창군</chargeNm><colorCd>진갈색</colorCd><desertionNo>448547201900361</desertionNo><filename>http://www.animal.go.kr/files/shelter/2019/09/201909191309413_s.jpg</filename><happenDt>20190919</happenDt><happenPlace>거창읍 동변리 1074</happenPlace><kindCd>[개] 믹스견</kindCd><neuterYn>U</neuterYn><noticeEdt>20190930</noticeEdt><noticeNo>경남-거창-2019-00362</noticeNo><noticeSdt>20190919</noticeSdt><officetel>055-940-8140</officetel><orgNm>경상남도 거창군</orgNm><popfile>http://www.animal.go.kr/files/shelter/2019/09/201909191309413.jpeg</popfile><processState>보호중</processState><sexCd>M</sexCd><specialMark>3개월 가량 강아지, 온순함</specialMark><weight>1.5(Kg)</weight></item><item><age>2019(년생)</age><careAddr>경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈�
for item in root.iter('item'):
    kind = item.find('kindCd').text
    description = item.find('specialMark').text
    print(f'{kind} | {description}')
# Out:
# [개] 믹스견 | 3개월 가량 강아지, 온순함
# [개] 믹스견 | 3개월 가량 강아지, 온순함
# [개] 믹스견 | 3개월 가량 강아지
# [개] 믹스견 | 3개월 가량 강아지, 온순함
# [개] 믹스견 | 3개월 가량 강아지, 온순함
# [개] 믹스견 | 특이사항 없음
# [개] 믹스견 | 칩X, 쫑긋한 귀, 윤기나는 털, 우아한 분위기, 사람을 좋아하고 사랑스러움
# [개] 믹스견 | 칩X, 가을 햇살처럼 밝은아이, 처진귀,동그란눈 까맣고 매끈한 코,짧은 다리
# [개] 믹스견 | 사지가 끝이 흰색임
# [개] 믹스견 | 겁이많음
# [개] 믹스견 | 공격적임
# [개] 믹스견 | 매우 순하고 사람을 잘 따름, 시베리안 잡종
# [개] 믹스견 | 마름.
# [개] 믹스견 | 믹스 갈색 수컷 3살 추정
# [개] 믹스견 | 흰팩에 꼬리가 길고 꼬리털이 복실복실함
# [개] 비숑 프리제 | 엄청난 똥꼬 발랄 엄청난 애교 엄청 사랑스러움 견주분을 발랄하게 기다라고 있습니다.
# [개] 믹스견 | 119소방대원을 매우 좋아함 성격이 매우 좋음.
# [고양이] 한국 고양이 | 매우 온순하며 사람을 좋아함
# [개] 믹스견 | 매우 온순하며 사람을 좋아함
# [개] 믹스견 | 매우 온순하며 사람을 좋아함

# %% [markdown]
# # 컬럼 목록 얻기
# ElementTree는 Iterator를 사용합니다.
#
# next 함수를 사용하면 for를 쓰지 않고도 직접 값을 얻을 수 있습니다.
#
# Iterator에 대한 파이썬 위키의 설명: https://wiki.python.org/moin/Iterator

# %%
# 첫번째 item을 얻습니다.

item = next(root.iter('item'))

item
# Out:
# <Element 'item' at 0x0000022B41C58188>

# %%
# item 바로 아래에 뭐가 있을까?

list(item)
# Out:
# [<Element 'age' at 0x0000022B41C581D8>,
#  <Element 'careAddr' at 0x0000022B41C58228>,
#  <Element 'careNm' at 0x0000022B41C58278>,
#  <Element 'careTel' at 0x0000022B41C582C8>,
#  <Element 'chargeNm' at 0x0000022B41C58318>,
#  <Element 'colorCd' at 0x0000022B41C58368>,
#  <Element 'desertionNo' at 0x0000022B41C583B8>,
#  <Element 'filename' at 0x0000022B41C58408>,
#  <Element 'happenDt' at 0x0000022B41C58458>,
#  <Element 'happenPlace' at 0x0000022B41C584A8>,
#  <Element 'kindCd' at 0x0000022B41C584F8>,
#  <Element 'neuterYn' at 0x0000022B41C58548>,
#  <Element 'noticeEdt' at 0x0000022B41C58598>,
#  <Element 'noticeNo' at 0x0000022B41C585E8>,
#  <Element 'noticeSdt' at 0x0000022B41C58638>,
#  <Element 'officetel' at 0x0000022B41C58688>,
#  <Element 'orgNm' at 0x0000022B41C586D8>,
#  <Element 'popfile' at 0x0000022B41C58728>,
#  <Element 'processState' at 0x0000022B41C58778>,
#  <Element 'sexCd' at 0x0000022B41C587C8>,
#  <Element 'specialMark' at 0x0000022B41C58818>,
#  <Element 'weight' at 0x0000022B41C58868>]

# %%
#컬럼 만들기
columns = []

for child in list(item):
    columns.append(child.tag)
    
print(columns)
# Out:
# ['age', 'careAddr', 'careNm', 'careTel', 'chargeNm', 'colorCd', 'desertionNo', 'filename', 'happenDt', 'happenPlace', 'kindCd', 'neuterYn', 'noticeEdt', 'noticeNo', 'noticeSdt', 'officetel', 'orgNm', 'popfile', 'processState', 'sexCd', 'specialMark', 'weight']

# %% [markdown]
# # XML 데이터를 Pandas로 변환
#
# https://pandas.pydata.org/

# %%
# pandas 사용

import pandas as pd

pd.__version__
# Out:
# '0.25.0'

# %%
# XML 데이터를 dictionary의 list로 만들기

rows = []

for item in root.iter('item'):
    row = {}
    for child in list(item):
        row[child.tag] = child.text
    rows.append(row)

print('갯수:', len(rows))
print()
print(rows[0])
# Out:
# 갯수: 20
#
# {'age': '2019(년생)', 'careAddr': '경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈퍼) ', 'careNm': '나래동물병원', 'careTel': '055-942-8875', 'chargeNm': '거창군', 'colorCd': '진갈색', 'desertionNo': '448547201900361', 'filename': 'http://www.animal.go.kr/files/shelter/2019/09/201909191309413_s.jpg', 'happenDt': '20190919', 'happenPlace': '거창읍 동변리 1074', 'kindCd': '[개] 믹스견', 'neuterYn': 'U', 'noticeEdt': '20190930', 'noticeNo': '경남-거창-2019-00362', 'noticeSdt': '20190919', 'officetel': '055-940-8140', 'orgNm': '경상남도 거창군', 'popfile': 'http://www.animal.go.kr/files/shelter/2019/09/201909191309413.jpeg', 'processState': '보호중', 'sexCd': 'M', 'specialMark': '3개월 가량 강아지, 온순함', 'weight': '1.5(Kg)'}

# %%
# DataFrame으로 만들기

df = pd.DataFrame(rows, columns=columns)

df
# Out:
#          age                                   careAddr      careNm  \
# 0   2019(년생)        경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈퍼)       나래동물병원
# 1   2019(년생)        경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈퍼)       나래동물병원
# 2   2019(년생)        경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈퍼)       나래동물병원
# 3   2019(년생)        경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈퍼)       나래동물병원
# 4   2019(년생)        경상남도 거창군 거창읍 거창대로 13-2 (거창읍, 칠성슈퍼)       나래동물병원
# 5   2018(년생)                    경상남도 고성군 고성읍 송학리 260-54    백호종합동물병원
# 6   2018(년생)  경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지    진해유기동물보호소
# 7   2018(년생)  경상남도 창원시 진해구 웅천로 218 (성내동, 농업기술센터) 205번지    진해유기동물보호소
# 8   2013(년생)            경상북도 영양군 입암면 마령산해로 1202 (입암면) .  영양군유기동물보호소
# 9   2016(년생)                  경상북도 군위군 군위읍 군청로 200 군위군청        군위군청
# 10  2015(년생)                  경상북도 군위군 군위읍 군청로 200 군위군청        군위군청
# 11  2019(년생)      경상북도 영천시 천문로 622-13 (오미동, 영천시농업기술센터)   영천유기동물보호센터
# 12  2014(년생)                전라남도 화순군 화순읍 한고을길 42 (화순읍)      화순위탁보호소
# 13  2016(년생)            전라남도 광양시 봉강면 인덕로 1169-20 (봉강면)    광양시 임시보호소
# 14  2018(년생)           전라북도 장수군 장수읍 군청길 16 (장수읍) 문 동물병원     문 동물병원
# 15  2019(년생)     전라북도 군산시 대야면 보덕안정길 108-20 (대야면) 군산도그랜드   군산유기동물보호소
# 16  2017(년생)     전라북도 군산시 대야면 보덕안정길 108-20 (대야면) 군산도그랜드   군산유기동물보호소
# 18       군산시 나포면 우곡제길 84-19  ...  20190930   전북-군산-2019-01100  20190919
# 19       군산시 나포면 우곡제길 84-19  ...  20190930   전북-군산-2019-01099  20190919
#
#        officetel         orgNm  \
# 0   055-940-8140      경상남도 거창군
# 1   055-940-8140      경상남도 거창군
# 2   055-940-8140      경상남도 거창군
# 3   055-940-8140      경상남도 거창군
# 4   055-940-8140      경상남도 거창군
# 5   055-670-4314      경상남도 고성군
# 6   055-225-5483  경상남도 창원시 진해구
# 7   055-225-5483  경상남도 창원시 진해구
# 8   054-680-6662      경상북도 영양군
# 9   054-380-6183      경상북도 군위군
# 10  054-380-6183      경상북도 군위군
# 11  054-339-7179      경상북도 영천시
# 12  061-379-3658      전라남도 화순군
# 13  061-797-3386      전라남도 광양시
# 14  063-350-2416      전라북도 장수군
# 15  063-454-5912      전라북도 군산시
# 16  063-454-5912      전라북도 군산시
# 17  063-454-5912      전라북도 군산시
# 18  063-454-5912      전라북도 군산시
# 19  063-454-5912      전라북도 군산시
#
#                                               popfile processState sexCd  \
# 0   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 1   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 2   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 3   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 4   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 5   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 6   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 7   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 8   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 9   http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 10  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 11  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
# 12  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 13  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 14  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 15  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 16  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 17  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 18  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     M
# 19  http://www.animal.go.kr/files/shelter/2019/09/...          보호중     F
#
#                                        specialMark   weight
# 0                                  3개월 가량 강아지, 온순함  1.5(Kg)
# 1                                  3개월 가량 강아지, 온순함    2(Kg)
# 2                                       3개월 가량 강아지    2(Kg)
# 3                                  3개월 가량 강아지, 온순함  1.5(Kg)
# 4                                  3개월 가량 강아지, 온순함    2(Kg)
# 5                                          특이사항 없음    6(Kg)
# 6       칩X, 쫑긋한 귀, 윤기나는 털, 우아한 분위기, 사람을 좋아하고 사랑스러움  3.5(Kg)
# 7       칩X, 가을 햇살처럼 밝은아이, 처진귀,동그란눈 까맣고 매끈한 코,짧은 다리  4.9(Kg)
# 8                                       사지가 끝이 흰색임    7(Kg)
# 9                                             겁이많음    4(Kg)
# 10                                            공격적임    4(Kg)
# 11                        매우 순하고 사람을 잘 따름, 시베리안 잡종    6(Kg)
# 12                                             마름.    9(Kg)
# 13                                  믹스 갈색 수컷 3살 추정   19(Kg)
# 14                           흰팩에 꼬리가 길고 꼬리털이 복실복실함   15(Kg)
# 15  엄청난 똥꼬 발랄 엄청난 애교 엄청 사랑스러움 견주분을 발랄하게 기다라고 있습니다.  1.1(Kg)
# 16                      119소방대원을 매우 좋아함 성격이 매우 좋음.  0.8(Kg)
# 17                                 매우 온순하며 사람을 좋아함  0.7(Kg)
# 18                                 매우 온순하며 사람을 좋아함  0.8(Kg)
# 19                                 매우 온순하며 사람을 좋아함  0.8(Kg)
#
# [20 rows x 22 columns]

# %%
data = df['age'].value_counts()

pd.DataFrame(data)
# Out:
#           age
# 2019(년생)   10
# 2018(년생)    4
# 2016(년생)    2
# 2013(년생)    1
# 2017(년생)    1
# 2014(년생)    1
# 2015(년생)    1

# %%
data = df['kindCd'].value_counts()

pd.DataFrame(data)
# Out:
#               kindCd
# [개] 믹스견           18
# [고양이] 한국 고양이       1
# [개] 비숑 프리제         1
