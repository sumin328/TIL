# %% [markdown]
# 환경변수 여러 개를 한꺼번에 설정합니다.
#
# 반드시 Key, Token 등의 내용을 바꿔서 입력해 주세요.
#
#     # 1. 공공데이터포털
#     # Mac, Linux 또는 Windows Git Bash 등에선 다음과 같이 export를 사용하시면 됩니다.
#     export ANIMAL_API_KEY=XTRdBWJdl4pV1%2FvSfZeu4FoGpl2eGP%2FzlR5eGh%2F9M8jbOv4HPFZI%2BM7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q%3D%3D
#     # Windows 기본 환경에선 다음과 같이 set을 사용하세요.
#     set ANIMAL_API_KEY=XTRdBWJdl4pV1%2FvSfZeu4FoGpl2eGP%2FzlR5eGh%2F9M8jbOv4HPFZI%2BM7ckZstS8OzkMKHNBkpAtdZX6T8VoRl4Q%3D%3D
#
#     # 2. LocationIQ
#     # Mac, Linux 또는 Windows Git Bash 등에선 다음과 같이 export를 사용하시면 됩니다.
#     export LOCATIONIQ_TOKEN=6b85c5308793d4
#     # Windows 기본 환경에선 다음과 같이 set을 사용하세요.
#     set LOCATIONIQ_TOKEN=6b85c5308793d4
#
#     # Jupyter Notebook 실행
#     jupyter notebook
#     환경 변수에서 API 키를 가져옵니다.

# %%
# 환경 변수에서 API 키 가져오기

import os
from urllib.parse import unquote

API_KEY = unquote(os.environ['ANIMAL_API_KEY'])
LOCATIONIQ_TOKEN = os.environ['LOCATIONIQ_TOKEN']

# %% [markdown]
# # 라이브러리 사용

# %%
# requests 사용

import requests

requests.__version__
# Out:
# '2.22.0'

# %%
# Pandas 사용

import pandas as pd

pd.__version__
# Out:
# '0.25.0'

# %%
# Matplotlib 사용

import matplotlib
import matplotlib.pyplot as plt

matplotlib.__version__
# Out:
# '3.1.1'

# %%
# matplotlib에 “AppleGothc”(Mac) 또는 “Malgun Gothic”(Windows) 글꼴 적용

import matplotlib.font_manager as fm

for font in fm.fontManager.ttflist:
    if font.name in ['AppleGothic', 'Malgun Gothic']:
        plt.rcParams['font.family'] = font.name
        break

plt.rcParams['font.family']
# Out:
# ['Malgun Gothic']

# %%
# folium 패키지 설치

# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\python37\lib\site-packages (0.10.0)
# Requirement already satisfied: numpy in c:\python37\lib\site-packages (from folium) (1.17.0)
# Requirement already satisfied: branca>=0.3.0 in c:\python37\lib\site-packages (from folium) (0.3.1)
# Requirement already satisfied: jinja2>=2.9 in c:\python37\lib\site-packages (from folium) (2.10.1)
# Requirement already satisfied: requests in c:\python37\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: six in c:\python37\lib\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\python37\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python37\lib\site-packages (from requests->folium) (2019.9.11)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\python37\lib\site-packages (from requests->folium) (1.25.3)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\python37\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\python37\lib\site-packages (from requests->folium) (3.0.4)
# WARNING: You are using pip version 19.2.2, however version 19.2.3 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# folium 버전 확인

import folium

folium.__version__
# Out:
# '0.10.0'

# %%
# folium 라이브러리의 Map과 HeatMap 사용

from folium import Map
from folium.plugins import HeatMap

# %% [markdown]
# # 동물보호관리시스템 유기동물 조회 서비스 API 사용
#
# 많은 데이터를 다루기 위해 한꺼번에 만 개를 얻어오겠습니다.

# %%
# 동물보호관리시스템 유기동물 조회 서비스 API

# 원래 URL: http://openapi.animal.go.kr/.../abandonmentPublic?serviceKey=어쩌고&bgnde=20190901&...

# 이렇게 긴 URL을 물음표(?)를 기준으로 두 부분으로 나눕니다.

# 물음표(?) 앞부분
url = 'http://openapi.animal.go.kr/openapi/service/rest/abandonmentPublicSrvc/abandonmentPublic'

# 물음표(?) 뒷부분
payload = {
    'serviceKey': API_KEY,
    'bgnde': '20190901',
    'endde': '20190930',
    'numOfRows': 10_000,
}

# API 호출
response = requests.get(url, params=payload)

print(response)
# Out:
# <Response [200]>

# %%
# Response의 Text 길이 확인

len(response.text)
# Out:
# 7400608

# %% [markdown]
# 표현에 주목해 보세요. reponse는 응답이고, response.text는 응답 받은 내용입니다. 우리가 파싱해야 하는 대상은 response.text겠죠?
#
# 파싱을 하면 우리가 다루기 좋은 트리가 만들어집니다.
#
# https://en.wikipedia.org/wiki/Tree_(data_structure)
#
# 컴퓨터의 폴더 구조가 전형적인 트리죠.
#
# 트리의 가장 중요한 특징은 우리가 뿌리를 통해 나무 전체를 다룰 수 있다는 겁니다. 예를 들어, Windows의 경우 C:\(C 드라이브 루트)에서 출발하면 모든 파일에 접근할 수 있죠.

# %%
# XML 데이터 파싱

import xml.etree.ElementTree as ET

root = ET.fromstring(response.text)

root
# Out:
# <Element 'response' at 0x00000270EBEE5F98>

# %% [markdown]
# XML에 있던 <item> 항목을 모두 얻어보겠습니다.
#
# ElementTree는 파이썬의 Iterator를 활용해서 이 기능을 제공합니다.
#
# https://wiki.python.org/moin/Iterator
#
# Iterator는 글을 읽는 어린아이의 손가락 같은 역할을 합니다. 지금 가르킨 글자를 읽고 다음 글자로 넘어가죠.

# %%
# 첫번째 내용을 얻고 다음으로 넘어갑니다.

item = next(root.iter('item'))

# Item에 어떤 내용이 있는지 확인합니다.

list(item)
# Out:
# [<Element 'age' at 0x00000270EBF1FA98>,
#  <Element 'careAddr' at 0x00000270EBF1FAE8>,
#  <Element 'careNm' at 0x00000270EBF1FB38>,
#  <Element 'careTel' at 0x00000270EBF1FB88>,
#  <Element 'chargeNm' at 0x00000270EBF1FBD8>,
#  <Element 'colorCd' at 0x00000270EBF1FC28>,
#  <Element 'desertionNo' at 0x00000270EBF1FC78>,
#  <Element 'filename' at 0x00000270EBF1FCC8>,
#  <Element 'happenDt' at 0x00000270EBF1FD18>,
#  <Element 'happenPlace' at 0x00000270EBF1FD68>,
#  <Element 'kindCd' at 0x00000270EBF1FDB8>,
#  <Element 'neuterYn' at 0x00000270EBF1FE08>,
#  <Element 'noticeEdt' at 0x00000270EBF1FE58>,
#  <Element 'noticeNo' at 0x00000270EBF1FEA8>,
#  <Element 'noticeSdt' at 0x00000270EBF1FEF8>,
#  <Element 'officetel' at 0x00000270EBF1FF48>,
#  <Element 'orgNm' at 0x00000270EBF1FF98>,
#  <Element 'popfile' at 0x00000270F00F3048>,
#  <Element 'processState' at 0x00000270F00F3098>,
#  <Element 'sexCd' at 0x00000270F00F30E8>,
#  <Element 'specialMark' at 0x00000270F00F3138>,
#  <Element 'weight' at 0x00000270F00F3188>]

# %%
# <kindCd> 항목을 확인해 봅니다.
# 트리에서 바로 아래에 있는 걸 “자녀”라고 부릅니다.

child = item.find('kindCd')

print(child)
# Out:
# <Element 'kindCd' at 0x00000270EBF1FDB8>

# %%
# 자녀의 내용(text)을 확인해 봅니다.

print(child.text)
# Out:
# [개] 푸들

# %%
# 이게 뭐였죠?

print(child.tag)
# Out:
# kindCd

# %%
# item의 모든 자녀 확인

for child in item:
    print(child.tag, child.text)
# Out:
# age 2016(년생)
# careAddr 경상남도 고성군 고성읍 송학리 260-54
# careNm 백호종합동물병원
# careTel 010-3551-8261
# chargeNm 이주영
# colorCd 흰색
# desertionNo 448542201900419
# filename http://www.animal.go.kr/files/shelter/2019/09/201909241409108_s.jpg
# happenDt 20190924
# happenPlace 경남 고성군 영오면 양산4길 12
# kindCd [개] 푸들
# neuterYn N
# noticeEdt 20191008
# noticeNo 경남-고성-2019-00332
# noticeSdt 20190924
# officetel 055-670-4314
# orgNm 경상남도 고성군
# popfile http://www.animal.go.kr/files/shelter/2019/09/201909241409108.jpg
# processState 보호중
# sexCd M
# specialMark 피모 불량
# weight 5(Kg)

# %%
# 컬럼 목록 얻기

item = next(root.iter('item'))

columns = []

for child in item:
    columns.append(child.tag)

columns
# Out:
# ['age',
#  'careAddr',
#  'careNm',
#  'careTel',
#  'chargeNm',
#  'colorCd',
#  'desertionNo',
#  'filename',
#  'happenDt',
#  'happenPlace',
#  'kindCd',
#  'neuterYn',
#  'noticeEdt',
#  'noticeNo',
#  'noticeSdt',
#  'officetel',
#  'orgNm',
#  'popfile',
#  'processState',
#  'sexCd',
#  'specialMark',
#  'weight']

# %% [markdown]
# 항상 최종 형태를 먼저 생각합니다. 테스트 코드로 쓰는 게 가장 좋고, 여의치 않다면 그에 준하는 모양을 간단히 잡아봅니다.
#
# Pandas로 다루는 2차원 데이터는 Column과 Row의 조화를 통해 구성되죠.
#
# Column은 이름이 있고, key-value 형태(dictionary)를 쓰면 매우 좋습니다.
#
# Row는 그냥 list로 충분하죠.
#
# 즉, 데이터는 dictionary의 list가 됩니다.
#
#     # item이 없을 때
#     rows = []
#
#     # item이 하나일 때
#     rows = [
#         { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' }
#     ]
#
#     # item이 여럿일 때
#     rows = [
#         { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' },
#         { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' },
#         { 'age': '어쩌고', 'kindCd': '저쩌고', 'weight': '이런 식으로...' }
#     ]
# 사실 2차원 데이터는 항상 이 모양이라고 보셔도 무방합니다.

# %%
# XML 데이터를 Pandas DataFrame으로 변환

# dictionary의 list를 준비합니다. 처음엔 0개죠.
rows = []

# item을 하나씩 rows에 넣을 겁니다.
for item in root.iter('item'):
    # 일단 row를 준비합니다. 단수형과 복수형을 구분해서 쓰니까 주의하세요.
    row = {}
    # item의 자녀를 하나씩 row에 넣을 겁니다.
    # 이런 코드가 나오면 앞에 나온 for는 잊어버리세요.
    # 지금부터 나오는 것에 집중하세요.
    for child in list(item):
        # dictionary는 key와 value를 함께 써서 추가 또는 변경합니다.
        # tag와 text가 헷갈리면 바로 위에 나온 ElementTree를 다시 확인하세요.
        # tag와 text는 보편적인 표현이 아닙니다.
        # A라는 폴더의 README.md 파일과 B라는 폴더의 README.md 파일은 이름이 같지만 전혀 다릅니다.
        # 어떤 게 들어있는지는 직접 열어보기 전에는 알 수 없습니다.
        # “모르는 것 발견 = 지금 당장 확인”을 습관으로 만드세요. 손은 눈보다 빠릅니다.
        row[child.tag] = child.text
    # 이렇게 블록이 끝나면 방금 있던 for를 잊으세요.
    # 우리가 얻은 건 item의 자녀 내용이 들어간 row죠.
    # 이제 이걸 rows(단수형과 복수형에 주의하세요)에 넣어줍니다.
    # list는 append를 썼죠?
    rows.append(row)

# dictionary의 list는 Pandas의 DataFrame으로 쉽게 변경 가능합니다.

df = pd.DataFrame(rows, columns=columns)

# %%
# 1. 컬럼 목록

df.columns
# Out:
# Index(['age', 'careAddr', 'careNm', 'careTel', 'chargeNm', 'colorCd',
#        'desertionNo', 'filename', 'happenDt', 'happenPlace', 'kindCd',
#        'neuterYn', 'noticeEdt', 'noticeNo', 'noticeSdt', 'officetel', 'orgNm',
#        'popfile', 'processState', 'sexCd', 'specialMark', 'weight'],
#       dtype='object')

# %%
# 2. 전체 갯수와 컬럼 갯수 확인

df.shape
# Out:
# (9444, 22)

# %%
# 3. 데이터 일부 확인

df.head()
# Out:
#         age                                careAddr    careNm        careTel  \
# 0  2016(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원  010-3551-8261
# 1  2017(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원  010-3551-8261
# 2  2019(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원  010-3551-8261
# 3  2019(년생)  경상남도 의령군 의령읍 의병로9동길 30 (의령읍) 의령군농업기술센터       전조동   055-570-4150
# 4  2019(년생)  경상남도 의령군 의령읍 의병로9동길 30 (의령읍) 의령군농업기술센터       전조동   055-570-4150
#
#   chargeNm    colorCd      desertionNo  \
# 0      이주영         흰색  448542201900419
# 1      이주영        흰갈색  448542201900416
# 2      이주영        고동색  448542201900415
# 3      의령군         흰색  448539201900058
# 4      의령군  검정,흰색갈색모색  448539201900057
#
#                                             filename  happenDt  \
# 0  http://www.animal.go.kr/files/shelter/2019/09/...  20190924
# 1  http://www.animal.go.kr/files/shelter/2019/09/...  20190924
# 2  http://www.animal.go.kr/files/shelter/2019/09/...  20190924
# 3  http://www.animal.go.kr/files/shelter/2019/09/...  20190924
# 4  http://www.animal.go.kr/files/shelter/2019/09/...  20190924
#
#             happenPlace  ... noticeEdt          noticeNo noticeSdt  \
# 0    경남 고성군 영오면 양산4길 12  ...  20191008  경남-고성-2019-00332  20190924
# 1  경남 고성군 하이면 월흥7길 11-3  ...  20191008  경남-고성-2019-00331  20190924
# 2    경남 고성군 고성읍 수남2길 39  ...  20191008  경남-고성-2019-00330  20190924
# 3     경남 의령군 용덕면 가락마을부근  ...  20191004  경남-의령-2019-00061  20190924
# 4     경남 의령군 용덕면 가락마을부근  ...  20191004  경남-의령-2019-00060  20190924
#
#       officetel     orgNm                                            popfile  \
# 0  055-670-4314  경상남도 고성군  http://www.animal.go.kr/files/shelter/2019/09/...
# 1  055-670-4314  경상남도 고성군  http://www.animal.go.kr/files/shelter/2019/09/...
# 2  055-670-4314  경상남도 고성군  http://www.animal.go.kr/files/shelter/2019/09/...
# 3  055-570-4153  경상남도 의령군  http://www.animal.go.kr/files/shelter/2019/09/...
# 4  055-570-4153  경상남도 의령군  http://www.animal.go.kr/files/shelter/2019/09/...
#
#   processState sexCd       specialMark weight
# 0          보호중     M             피모 불량  5(Kg)
# 1          보호중     M           특이사항 없음  6(Kg)
# 2          보호중     M           특이사항 없음  4(Kg)
# 3          보호중     F  사람 잘따름,많이 작은 사이즈  4(Kg)
# 4          보호중     F         암컷강아지 두마리  4(Kg)
#
# [5 rows x 22 columns]

# %%
# 컬럼별 결측값 갯수 확인

data = df.isnull().sum()

pd.DataFrame(data)
# Out:
#                 0
# age             0
# careAddr        0
# careNm          0
# careTel         0
# chargeNm      207
# colorCd         0
# desertionNo     0
# filename        0
# happenDt        0
# happenPlace     0
# kindCd          0
# neuterYn        0
# noticeEdt       0
# noticeNo        0
# noticeSdt       0
# officetel     543
# orgNm           0
# popfile         0
# processState    0
# sexCd           0
# specialMark     0
# weight          0

# %%
# 안 쓰는 컬럼 이름을 넣어 drop해서 simple 데이터 만들기

simple_df = df.drop(columns=[
    'careTel', 'desertionNo', 'filename',
    'noticeEdt', 'noticeNo', 'noticeSdt', 'officetel', 'popfile'
])

# 정리된 데이터 확인

simple_df.head()
# Out:
#         age                                careAddr    careNm chargeNm  \
# 0  2016(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원      이주영
# 1  2017(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원      이주영
# 2  2019(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원      이주영
# 3  2019(년생)  경상남도 의령군 의령읍 의병로9동길 30 (의령읍) 의령군농업기술센터       전조동      의령군
# 4  2019(년생)  경상남도 의령군 의령읍 의병로9동길 30 (의령읍) 의령군농업기술센터       전조동      의령군
#
#      colorCd  happenDt           happenPlace   kindCd neuterYn     orgNm  \
# 0         흰색  20190924    경남 고성군 영오면 양산4길 12   [개] 푸들        N  경상남도 고성군
# 1        흰갈색  20190924  경남 고성군 하이면 월흥7길 11-3  [개] 믹스견        N  경상남도 고성군
# 2        고동색  20190924    경남 고성군 고성읍 수남2길 39  [개] 믹스견        N  경상남도 고성군
# 3         흰색  20190924     경남 의령군 용덕면 가락마을부근  [개] 믹스견        U  경상남도 의령군
# 4  검정,흰색갈색모색  20190924     경남 의령군 용덕면 가락마을부근  [개] 믹스견        U  경상남도 의령군
#
#   processState sexCd       specialMark weight
# 0          보호중     M             피모 불량  5(Kg)
# 1          보호중     M           특이사항 없음  6(Kg)
# 2          보호중     M           특이사항 없음  4(Kg)
# 3          보호중     F  사람 잘따름,많이 작은 사이즈  4(Kg)
# 4          보호중     F         암컷강아지 두마리  4(Kg)

# %% [markdown]
# # 데이터 살펴보기

# %%
# 갯수 세기

data = simple_df['age'].value_counts()

pd.DataFrame(data)
# Out:
#            age
# 2019(년생)  4729
# 2018(년생)  1183
# 2017(년생)  1161
# 2016(년생)   879
# 2014(년생)   405
# 2015(년생)   381
# 2013(년생)   224
# 2009(년생)   140
# 2012(년생)   122
# 2011(년생)   110
# 2010(년생)    27
# 2007(년생)    23
# 2004(년생)    19
# 2006(년생)    12
# 2005(년생)    11
# 2008(년생)    11
# 2003(년생)     3
# 2002(년생)     3
# 2001(년생)     1

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['sexCd'].value_counts()

pd.DataFrame(data)
# Out:
#    sexCd
# M   4424
# F   4179
# Q    841

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['neuterYn'].value_counts()

pd.DataFrame(data)
# Out:
#    neuterYn
# N      5975
# U      3061
# Y       408

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['kindCd'].value_counts()

pd.DataFrame(data)
# Out:
#                     kindCd
# [개] 믹스견               4550
# [고양이] 한국 고양이          2136
# [개] 말티즈                436
# [개] 푸들                 381
# [개] 진도견                237
# ...                    ...
# [개] 스피츠 믹스               1
# [고양이] 고등어                1
# [개] 호피견                  1
# [개] 아메리칸 스태퍼드셔 테리어       1
# [개] 벨지안 셰퍼드 독            1
#
# [158 rows x 1 columns]

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['colorCd'].value_counts()

pd.DataFrame(data)
# Out:
#            colorCd
# 흰색            1730
# 갈색             913
# 검정             341
# 흰              285
# 삼색             169
# ...            ...
# 검,회색             1
# 검회색/은색           1
# 갈색,검정.흰색         1
# 흰/연회             1
# 검정, 흰색 믹스        1
#
# [1098 rows x 1 columns]

# %%
# 파이 그래프

# 데이터가 너무 많아서 20개로 제한
data = simple_df['colorCd'].value_counts().nlargest(20)

data.plot.pie()

plt.show()

# %%
# 갯수 세기

data = simple_df['happenDt'].value_counts()

pd.DataFrame(data)
# Out:
#           happenDt
# 20190916       789
# 20190902       661
# 20190909       619
# 20190918       609
# 20190917       572
# 20190920       529
# 20190910       522
# 20190911       521
# 20190919       508
# 20190905       504
# 20190903       479
# 20190904       472
# 20190923       460
# 20190906       446
# 20190921       226
# 20190912       219
# 20190907       214
# 20190924       203
# 20190915       192
# 20190914       175
# 20190908       171
# 20190901       149
# 20190913       112
# 20190922        92

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %%
# 요일 구하기 

DAYS = '일월화수목금토'

weekdays = []

for index in df.index:
    date = simple_df['happenDt'][index]
    # 2019년 9월 1일은 “일요일(0)”입니다.
    weekday = (int(date) - 20190901) % 7
    weekdays.append(DAYS[weekday])

simple_df = simple_df.assign(happenDay=weekdays)

simple_df.head()
# Out:
#         age                                careAddr    careNm chargeNm  \
# 0  2016(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원      이주영
# 1  2017(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원      이주영
# 2  2019(년생)                 경상남도 고성군 고성읍 송학리 260-54  백호종합동물병원      이주영
# 3  2019(년생)  경상남도 의령군 의령읍 의병로9동길 30 (의령읍) 의령군농업기술센터       전조동      의령군
# 4  2019(년생)  경상남도 의령군 의령읍 의병로9동길 30 (의령읍) 의령군농업기술센터       전조동      의령군
#
#      colorCd  happenDt           happenPlace   kindCd neuterYn     orgNm  \
# 0         흰색  20190924    경남 고성군 영오면 양산4길 12   [개] 푸들        N  경상남도 고성군
# 1        흰갈색  20190924  경남 고성군 하이면 월흥7길 11-3  [개] 믹스견        N  경상남도 고성군
# 2        고동색  20190924    경남 고성군 고성읍 수남2길 39  [개] 믹스견        N  경상남도 고성군
# 3         흰색  20190924     경남 의령군 용덕면 가락마을부근  [개] 믹스견        U  경상남도 의령군
# 4  검정,흰색갈색모색  20190924     경남 의령군 용덕면 가락마을부근  [개] 믹스견        U  경상남도 의령군
#
#   processState sexCd       specialMark weight happenDay
# 0          보호중     M             피모 불량  5(Kg)         화
# 1          보호중     M           특이사항 없음  6(Kg)         화
# 2          보호중     M           특이사항 없음  4(Kg)         화
# 3          보호중     F  사람 잘따름,많이 작은 사이즈  4(Kg)         화
# 4          보호중     F         암컷강아지 두마리  4(Kg)         화

# %%
# 갯수 세기

data = simple_df['happenDay'].value_counts()

pd.DataFrame(data)
# Out:
#    happenDay
# 월       2529
# 화       1776
# 수       1602
# 목       1231
# 금       1087
# 토        615
# 일        604

# %%
# 파이 그래프

data.plot.pie()

plt.show()

# %% [markdown]
# # 위도/경도 얻기
#
# 반복적으로 써야 하니 함수를 만듭니다.

# %%
def geocode(address):
    url = 'https://us1.locationiq.com/v1/search.php'
    payload = {
        'key': LOCATIONIQ_TOKEN,
        'q': address,
        'format': 'json'
    }
    response = requests.get(url, params=payload)
    results = response.json()
    if 'error' in results:
        return None, None
    coordinates = results[0]
    return coordinates['lat'], coordinates['lon']

# %%
geocode('서울창업허브')
# Out:
# ('37.54662875', '126.949684293519')

# %%
geocode('이 세계 어디에도 없는 주소')
# Out:
# (None, None)

# %%
# API 호출 및 지도에 표시하는 작업을 원활히 하기 위해 자료를 500개로 제한해서 sample 데이터를 만듭니다.

sample_df = simple_df.sample(n=500, random_state=1)

sample_df.shape
# Out:
# (500, 15)

# %%
# 위도, 경도 얻기

lats = []
lngs = []

for i, index in enumerate(sample_df.index):
    print(i + 1, '-', index)
    lat, lng = geocode(sample_df['orgNm'][index])
    lats.append(lat or 0)
    lngs.append(lng or 0)

sample_df = sample_df.assign(lat=lats, lng=lngs)

sample_df.head()
# Out:
# 1 - 4177
# 2 - 1183
# 3 - 2864
# 4 - 8909
# 5 - 6243
# 6 - 9264
# 7 - 7911
# 8 - 4638
# 9 - 6672
# 10 - 8838
# 11 - 4381
# 12 - 6434
# 13 - 3568
# 14 - 5645
# 15 - 4555
# 16 - 6111
# 17 - 1104
# 18 - 2161
# 19 - 8281
# 20 - 2106
# 21 - 1520
# 22 - 1266
# 23 - 254
# 24 - 5417
# 25 - 2257
# 26 - 5108
# 27 - 9047
# 28 - 1338
# 29 - 6483
# 30 - 5526
# 31 - 4153
# 32 - 695
# 33 - 3789
# 34 - 8026
# 35 - 2651
# 36 - 2707
# 37 - 5025
# 38 - 7839
# 39 - 3707
# 40 - 234
# 41 - 2762
# 42 - 6729
# 43 - 1510
# 44 - 8866
# 45 - 2150
# 46 - 2061
# 47 - 8168
# 48 - 8954
# 49 - 6155
# 50 - 4100
# 51 - 4082
# 52 - 2571
# 53 - 5029
# 54 - 2351
# 55 - 691
# 56 - 7964
# 57 - 5245
# 58 - 3942
# 59 - 7062
# 60 - 6296
# 61 - 274
# 62 - 783
# 63 - 1332
# 64 - 5739
# 65 - 7275
# 66 - 7568
# 67 - 2398
# 68 - 2545
# 69 - 1777
# 70 - 3397
# 71 - 3432
# 72 - 685
# 73 - 2012
# 74 - 1893
# 75 - 5221
# 76 - 7070
# 77 - 6443
# 78 - 5890
# 79 - 7266
# 80 - 4033
# 81 - 4133
# 82 - 2992
# 83 - 8553
# 84 - 3211
# 85 - 8744
# 86 - 1005
# 87 - 4894
# 88 - 1406
# 89 - 337
# 90 - 6066
# 91 - 3798
# 92 - 8523
# 93 - 6618
# 94 - 229
# 95 - 4346
# 96 - 923
# 97 - 3544
# 98 - 1750
# 99 - 4248
# 100 - 4211
# 101 - 8592
# 102 - 6925
# 103 - 7689
# 104 - 6634
# 105 - 9123
# 106 - 3841
# 107 - 8727
# 108 - 8949
# 109 - 8962
# 110 - 4543
# 111 - 1685
# 112 - 911
# 113 - 2213
# 114 - 5833
# 115 - 5045
# 116 - 6697
# 117 - 8486
# 118 - 6325
# 119 - 8179
# 120 - 2983
# 121 - 6702
# 122 - 9285
# 123 - 2653
# 124 - 7042
# 125 - 4300
# 126 - 526
# 127 - 8550
# 128 - 2481
# 129 - 4520
# 130 - 8084
# 131 - 8428
# 132 - 3123
# 133 - 7161
# 134 - 3201
# 135 - 67
# 136 - 6633
# 137 - 1297
# 138 - 5190
# 139 - 2706
# 140 - 8653
# 141 - 2456
# 142 - 3809
# 143 - 8406
# 144 - 2201
# 145 - 2963
# 146 - 1910
# 147 - 4076
# 148 - 3363
# 149 - 8854
# 150 - 4452
# 151 - 2452
# 152 - 6445
# 153 - 5376
# 154 - 9307
# 155 - 428
# 156 - 2210
# 157 - 7905
# 158 - 1122
# 159 - 6946
# 160 - 8131
# 161 - 2740
# 162 - 5338
# 163 - 1011
# 164 - 7378
# 165 - 1731
# 166 - 575
# 167 - 6097
# 168 - 4875
# 169 - 5061
# 170 - 7349
# 171 - 5954
# 172 - 7138
# 173 - 8491
# 174 - 3259
# 175 - 5981
# 176 - 2400
# 177 - 220
# 178 - 8786
# 179 - 2242
# 180 - 3481
# 181 - 82
# 182 - 4111
# 183 - 7966
# 184 - 7373
# 185 - 4017
# 186 - 45
# 187 - 128
# 188 - 2582
# 189 - 3840
# 190 - 5900
# 191 - 7724
# 192 - 5174
# 193 - 4825
# 194 - 9092
# 195 - 3205
# 196 - 7869
# 197 - 725
# 198 - 8164
# 199 - 8698
# 200 - 3042
# 201 - 7625
# 202 - 8355
# 203 - 834
# 204 - 2045
# 205 - 2495
# 206 - 6619
# 207 - 574
# 208 - 4046
# 209 - 5989
# 210 - 6821
# 211 - 6986
# 212 - 9180
# 213 - 3027
# 214 - 6529
# 215 - 1735
# 216 - 5563
# 217 - 627
# 218 - 6775
# 219 - 307
# 220 - 587
# 221 - 4515
# 222 - 1271
# 223 - 6707
# 224 - 8097
# 225 - 2684
# 226 - 8215
# 227 - 7589
# 228 - 3497
# 229 - 7738
# 230 - 5330
# 231 - 509
# 232 - 9150
# 233 - 7454
# 234 - 9125
# 235 - 5871
# 236 - 3531
# 237 - 6251
# 238 - 1806
# 239 - 7993
# 240 - 7049
# 241 - 1125
# 242 - 2455
# 243 - 4761
# 244 - 4228
# 245 - 2182
# 246 - 1242
# 247 - 1216
# 248 - 1167
# 249 - 1264
# 250 - 8101
# 251 - 6992
# 252 - 3807
# 253 - 4318
# 254 - 7316
# 255 - 98
# 256 - 7868
# 257 - 5515
# 258 - 4023
# 259 - 4481
# 260 - 3977
# 261 - 4331
# 262 - 8969
# 263 - 1892
# 264 - 7146
# 265 - 1718
# 266 - 5765
# 267 - 3516
# 268 - 5425
# 269 - 5982
# 270 - 1488
# 271 - 7392
# 272 - 1233
# 273 - 5709
# 274 - 6341
# 275 - 6169
# 276 - 5783
# 277 - 6708
# 278 - 5683
# 279 - 2947
# 280 - 147
# 281 - 2167
# 282 - 895
# 283 - 6012
# 284 - 8682
# 285 - 8250
# 286 - 3556
# 287 - 7092
# 288 - 712
# 289 - 9006
# 290 - 961
# 291 - 6582
# 292 - 308
# 293 - 2039
# 294 - 7242
# 295 - 6839
# 296 - 9133
# 297 - 4434
# 298 - 5949
# 299 - 7112
# 300 - 8149
# 301 - 3353
# 302 - 2492
# 303 - 8805
# 304 - 5527
# 305 - 288
# 306 - 5995
# 307 - 6011
# 308 - 2512
# 309 - 9387
# 310 - 4837
# 311 - 3555
# 312 - 2226
# 313 - 2954
# 314 - 5613
# 315 - 8680
# 316 - 8765
# 317 - 728
# 318 - 3709
# 319 - 437
# 320 - 4453
# 321 - 3563
# 322 - 8683
# 323 - 6118
# 324 - 1432
# 325 - 7350
# 326 - 7587
# 327 - 806
# 328 - 5472
# 329 - 8064
# 330 - 5054
# 331 - 2328
# 332 - 2255
# 333 - 7250
# 334 - 3342
# 335 - 8816
# 336 - 4592
# 337 - 4304
# 338 - 6442
# 339 - 8591
# 340 - 8770
# 341 - 781
# 342 - 6204
# 343 - 4809
# 344 - 136
# 345 - 2938
# 346 - 7331
# 347 - 6106
# 348 - 9089
# 349 - 3679
# 350 - 619
# 351 - 6896
# 352 - 9052
# 353 - 7460
# 354 - 939
# 355 - 6840
# 356 - 8914
# 357 - 8471
# 358 - 550
# 359 - 2103
# 360 - 1691
# 361 - 3216
# 362 - 8799
# 363 - 9311
# 364 - 9046
# 365 - 6
# 366 - 8132
# 367 - 3496
# 368 - 6187
# 369 - 8548
# 370 - 9421
# 371 - 9261
# 372 - 8025
# 373 - 2973
# 374 - 1715
# 375 - 1315
# 376 - 6766
# 377 - 3705
# 378 - 1820
# 379 - 8803
# 380 - 1185
# 381 - 3298
# 382 - 2008
# 383 - 6739
# 384 - 6885
# 385 - 6314
# 386 - 8626
# 387 - 3207
# 388 - 3627
# 389 - 5184
# 390 - 1262
# 391 - 9211
# 392 - 7843
# 393 - 6293
# 394 - 6333
# 395 - 8293
# 396 - 8210
# 397 - 3192
# 398 - 5339
# 399 - 7617
# 400 - 2458
# 401 - 9400
# 402 - 2979
# 403 - 2217
# 404 - 5520
# 405 - 8063
# 406 - 146
# 407 - 3732
# 408 - 6261
# 409 - 6577
# 410 - 8234
# 411 - 4009
# 412 - 2619
# 413 - 2205
# 414 - 5633
# 415 - 6767
# 416 - 1515
# 417 - 1225
# 418 - 9423
# 419 - 8004
# 420 - 4286
# 421 - 5106
# 422 - 2263
# 423 - 1217
# 424 - 1165
# 425 - 9297
# 426 - 7967
# 427 - 5684
# 428 - 1435
# 429 - 2487
# 430 - 3219
# 431 - 8472
# 432 - 2730
# 433 - 4658
# 434 - 7702
# 435 - 7115
# 436 - 8848
# 437 - 5978
# 438 - 9388
# 439 - 2943
# 440 - 4579
# 441 - 2385
# 442 - 4386
# 443 - 3722
# 444 - 4370
# 445 - 3868
# 446 - 5838
# 447 - 2430
# 448 - 8228
# 449 - 3335
# 450 - 5812
# 451 - 4396
# 452 - 6625
# 453 - 2158
# 454 - 8982
# 455 - 2539
# 456 - 1288
# 457 - 2247
# 458 - 4989
# 459 - 1424
# 460 - 4613
# 461 - 830
# 462 - 822
# 463 - 5442
# 464 - 763
# 465 - 8616
# 466 - 2909
# 467 - 1797
# 468 - 8470
# 469 - 5669
# 470 - 3632
# 471 - 5448
# 472 - 4200
# 473 - 3224
# 474 - 4189
# 475 - 2940
# 476 - 5170
# 477 - 6909
# 478 - 8009
# 479 - 2874
# 480 - 2984
# 481 - 7043
# 482 - 891
# 483 - 1392
# 484 - 161
# 485 - 6262
# 486 - 2666
# 487 - 2098
# 488 - 3604
# 489 - 2300
# 490 - 4069
# 491 - 1756
# 492 - 1475
# 493 - 2463
# 494 - 1986
# 495 - 8274
# 496 - 7
# 497 - 1141
# 498 - 1038
# 499 - 7783
# 500 - 6022
#            age                                           careAddr  \
# 4177  2019(년생)                            대구광역시 서구 달서로 165 (비산동)
# 1183  2019(년생)                            경상북도 경주시 금성로 385 (성건동)
# 2864  2014(년생)                             경기도 양주시 남면 감악산로 63-37
# 8909  2016(년생)              대전광역시 유성구 갑동로15번길 20-39 (갑동) 대전동물보호센터
# 6243  2014(년생)  경기도 고양시 덕양구 고양대로 1695 (원흥동, 고양시 농업기술센터) 고양시동물보호센터
#
#            careNm chargeNm colorCd  happenDt             happenPlace   kindCd  \
# 4177  대구시수의사회(보경)      석주연      갈색  20190915          서구 내당4동 파출소 부근  [개] 믹스견
# 1183       가나동물병원      경주시  화이트브라운  20190920               불국사삼거리 인근  [개] 믹스견
# 2864   한국동물구조관리협회      유준석     갈/흰  20190917         도림동 고추말어린이공원 일대  [개] 치와와
# 8909     대전동물보호센터      김미중       황  20190902  대전광역시 유성구 봉명동 유성우체국 인근   [개] 푸들
# 6243    고양시동물보호센터      김유미      흰색  20190909       성석동 195-40 뉴 파인빌앞  [개] 믹스견
#
#      neuterYn       orgNm processState sexCd  \
# 4177        N    대구광역시 서구          보호중     F
# 1183        N    경상북도 경주시          보호중     M
# 2864        N  서울특별시 영등포구          보호중     M
# 8909        U   대전광역시 유성구       종료(반환)     M
# 6243        U     경기도 고양시       종료(입양)     F
#
#                              specialMark    weight happenDay         lat  \
# 4177                     이빨나지 않은 상태 1개월령     1(Kg)         일     35.8716
# 1183                                 온순함     3(Kg)         금  35.8556705
# 2864  동물병원에서목욕시킴.양윗송곳니유치남음.얌전함/사람따름.양슬개골   2.4(Kg)         화     37.5262
# 8909                                부분미용  5.00(Kg)         월     36.3622
# 6243                                  없음    21(Kg)         월           0
#
#               lng
# 4177     128.5591
# 1183  129.2248811
# 2864     126.8959
# 8909     127.3563
# 6243            0

# %% [markdown]
# # 지도 그리기
#
# 위도/경도 데이터를 얻었기 때문에 지도를 그려볼 수 있음

# %%
# 위도, 경도만 모읍니다.

coordinates = sample_df[['lat', 'lng']]

coordinates
# Out:
#              lat          lng
# 4177     35.8716     128.5591
# 1183  35.8556705  129.2248811
# 2864     37.5262     126.8959
# 8909     36.3622     127.3563
# 6243           0            0
# ...          ...          ...
# 7     35.3225404  128.2616485
# 1141  37.5120999     126.9395
# 1038           0            0
# 7783           0            0
# 6022     35.8296     128.5331
#
# [500 rows x 2 columns]

# %%
# 지도 준비

map = Map(location=[36.5, 127.5], zoom_start=7)

# 지도에 위치 표시

for lat, lng in coordinates.values:
    marker = folium.Circle(
        location=[lat, lng],
        radius=5_000,
        weight=1,
        fill_color='#F00',
        fill_opacity=0.3,
    )
    marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
